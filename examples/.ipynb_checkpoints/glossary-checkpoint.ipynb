# %%
# !pip install sentence_transformers
# !pip install langchain_community
# !pip install neo4j

# %%
import os
from bs4 import BeautifulSoup
from langchain_community.graphs import Neo4jGraph
from langchain_community.vectorstores import Neo4jVector
from langchain.text_splitter import RecursiveCharacterTextSplitter, SentenceTransformersTokenTextSplitter
from langchain.chains import RetrievalQAWithSourcesChain
import warnings
from langchain_community.document_loaders import DirectoryLoader
warnings.filterwarnings("ignore")
from langchain_community.embeddings import HuggingFaceEmbeddings
from sentence_transformers import CrossEncoder
import numpy as np
import re
from IPython.core.display import display, HTML
import json

# %%
# NEO4J_URI = 'bolt://citz-imb-ai-neo4j-svc:7687'
NEO4J_URI = 'bolt://' + 'localhost'+':7687'
NEO4J_USERNAME = 'neo4j'
NEO4J_PASSWORD = 'neo4j'
NEO4J_DATABASE = 'neo4j' #os.getenv('NEO4J_DB')
print(NEO4J_URI)
print(NEO4J_DATABASE)
# Out:
# bolt://localhost:7687
# neo4j

# %%
kg = Neo4jGraph(
    url=NEO4J_URI, username=NEO4J_USERNAME, password=NEO4J_PASSWORD, database=NEO4J_DATABASE
)

# %%
cypher = """
  MATCH (n) 
  RETURN count(n)
  """
result = kg.query(cypher)
result
# Out:
# [{'count(n)': 156403}]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap  = 200,
    length_function = len,
    separators=["\n\n", "\n", ". ", " ", ""],
)

# %% [markdown]
# ## Please download the glossary file from S3 before running the below code
# if you have the s3 credentials you can excute these commands in the notebook it self
# ```
# from utility.s3_glossary import download_data
# bucket_name = "IMBAIPilot"
# download_data("bclaws/glossary", "JSON_glossary/", bucket_name)
# ```
#
# You can also manually download this by executing the script in the utility folder

# %%
file_metadata = lambda x: {"filename": x}
f = open('/Users/msihag/repos/citz-imb-ai/JSON_glossary/glossary.json')
glossaries = json.load(f)

# %%
print(glossaries)
# Out:
# {'terms': [{'term': 'Act', 'description': 'Also called a statute. When a Bill (proposed law) passes third reading in the Legislative Assembly, and receives Royal Assent, it is thereby enacted and becomes an Act or law. Public Statutes generally deal with issues of significance for the whole province. Private, Local and Special Statutes are enacted by the Legislature on behalf of a person, a group, a municipality or a corporation, and affect only the interests of that person or group.', 'related_terms': ['Bill', 'Regulation']}, {'term': 'Adjournment', 'description': 'An adjournment temporarily ends a sitting or a Session. All business not concluded at the time of adjournment is resumed at the next sitting or Session.', 'related_terms': ['Dissolution', 'Prorogation']}, {'term': 'Amendment', 'description': 'A modification made to the text of a Bill, Act or regulation by adding, removing or substituting text.', 'related_terms': []}, {'term': 'Amended Bill', 'description': 'See Report Bill.', 'related_terms': ['Report Bill']}, {'term': 'Amending Bill', 'description': 'A Bill that proposes to amend an existing Act by adding, removing or substituting text in the existing Act.', 'related_terms': ['Bill', 'Act']}, {'term': 'Amending Regulation', 'description': 'A regulation that amends an existing regulation or Act by adding, removing or substituting text.', 'related_terms': ['Regulation', 'Act']}, {'term': 'Annual Bound Statutes (Buckram Bound, hardcover)', 'description': "Annual Bound Statutes (Buckram Bound, hardcover) After the end of each calendar year, the King's Printer publishes an official hardcover version of all new Acts and amendment Acts, both public and private, that were enacted during the year. In the case of private Acts, the hardcover edition is likely the final publication, since most private Acts are rarely consolidated or revised. The hardcover version includes a cumulative Table of Legislative Changes. The Annual Statutes dating back to 1858 are available on BC Laws.", 'related_terms': ['Consolidated Statutes', 'Official Version']}, {'term': 'Bill', 'description': "A proposed law that is introduced to the Legislative Assembly for review and debate. A Bill becomes an Act (law) when it passes third reading. There are 3 types of Bill: Public Bills (generally deal with issues of significance for the whole province): A Government Bill is a public Bill introduced by a minister of the government, which reflects government policy. A Member's Bill is a public Bill introduced by an opposition MLA, or a government MLA who is not a minister. Private Bills (generally deal with a specific issue affecting a person or group): A Private Bill is introduced by an MLA on behalf of a person or a group outside the Legislative Assembly. When enacted they are called Private, Special or Local Acts.", 'related_terms': ['Bill Stages', 'First Reading', 'Second Reading', 'Third Reading']}, {'term': 'Bill Stages', 'description': 'A Bill must pass through the following stages before it becomes law: first reading, second reading, committee, report, third reading, Royal Assent. Not all Bills complete the process.', 'related_terms': ['Bill', 'First Reading', 'Second Reading', 'Third Reading']}, {'term': 'Cabinet', 'description': 'Members of the governing party who have been appointed ministers (heads of government ministries). Also called the Executive Council.', 'related_terms': ['Executive Council']}, {'term': 'Chapter Numbers', 'description': 'When a Bill becomes an Act, as soon as it receives Royal Assent it is assigned a chapter number. The Act is then cited by its chapter number and year of passage; for example, the Greenhouse Gas Reduction Targets Act, introduced as Bill 17 of 2007, became Chapter 42 of the Statutes of British Columbia 2007, and is cited as S.B.C. 2007, c.42.', 'related_terms': ['Bill', 'Act']}, {'term': 'Citation', 'description': 'The numerical reference for a statute or regulation; for example, the citation for the Adopti ...

# %%
token_splitter = SentenceTransformersTokenTextSplitter(chunk_overlap=20, tokens_per_chunk=256)
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
merge_chunk_node_query = """
MERGE(mergedChunk:UpdatedChunk {chunkId: $chunkParam.chunkId})
    ON CREATE SET 
        mergedChunk.chunkSeqId = $chunkParam.chunkSeqId, 
        mergedChunk.text = $chunkParam.text,
        mergedChunk.type = $chunkParam.type,
        mergedChunk.url = $chunkParam.url,
        mergedChunk.glossaryTerm = $chunkParam.glossaryTerm
RETURN mergedChunk
"""

# %%
create_embeddings = """
        MATCH (chunk:UpdatedChunk) WHERE
        chunk.chunkId = $chunkParam.chunkId
        AND chunk.chunkSeqId = $chunkParam.chunkSeqId
        AND chunk.text = $chunkParam.text
        AND chunk.type = $chunkParam.type
        AND chunk.url = $chunkParam.url
        AND chunk.glossaryTerm = $chunkParam.glossaryTerm
        AND chunk.textEmbedding is NULL
        CALL db.create.setNodeVectorProperty(chunk, "textEmbedding", $vector)
        RETURN chunk
    """

# %%
# Total number of glossaries in bc gov
print(len(glossaries['terms']))
# Out:
# 67

# %% [markdown]
# ## This code below will create the chunk and embeddings of the glossary terms

# %%
for glossary in enumerate(glossaries['terms']):
    #print(glossary)
    #print(glossary[1]['term'])
    #print(glossary[1]['description'])
    #print(glossary[1]['related_terms'])
    text = glossary[1]['term'] + ': ' + glossary[1]['description']
    #print(item_text_chunks)
    token_split_texts = []
    data_type = 'glossary'
    # Validate if all the text fits into the 256 token size to create the embeddings
    token_split_texts += token_splitter.split_text(text)
    #print(token_split_texts)
    # create meta data
    for chunk_seq, token in enumerate(token_split_texts):
        chunk = {
            'type': data_type,
            'text': token,
            'chunkSeqId': chunk_seq,
            'chunkId': f'{data_type}-{glossary[1]["term"]}-seq-{str(chunk_seq)}',
            'url': 'https://www.bclaws.gov.bc.ca/glossary.html',
            'glossaryTerm': glossary[1]['term']
        }
        print(chunk)
        kg.query(merge_chunk_node_query, 
            params={
                'chunkParam': chunk
            })
        vector = embeddings.embed_query(chunk['text'])
        result = kg.query(create_embeddings, params={'chunkParam':chunk, 'vector':vector})
# Out:
# {'type': 'glossary', 'text': 'act : also called a statute. when a bill ( proposed law ) passes third reading in the legislative assembly, and receives royal assent, it is thereby enacted and becomes an act or law. public statutes generally deal with issues of significance for the whole province. private, local and special statutes are enacted by the legislature on behalf of a person, a group, a municipality or a corporation, and affect only the interests of that person or group.', 'chunkSeqId': 0, 'chunkId': 'glossary-Act-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Act'}
# {'type': 'glossary', 'text': 'adjournment : an adjournment temporarily ends a sitting or a session. all business not concluded at the time of adjournment is resumed at the next sitting or session.', 'chunkSeqId': 0, 'chunkId': 'glossary-Adjournment-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Adjournment'}
# {'type': 'glossary', 'text': 'amendment : a modification made to the text of a bill, act or regulation by adding, removing or substituting text.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amendment-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Amendment'}
# {'type': 'glossary', 'text': 'amended bill : see report bill.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amended Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Amended Bill'}
# {'type': 'glossary', 'text': 'amending bill : a bill that proposes to amend an existing act by adding, removing or substituting text in the existing act.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amending Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Amending Bill'}
# {'type': 'glossary', 'text': 'amending regulation : a regulation that amends an existing regulation or act by adding, removing or substituting text.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amending Regulation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Amending Regulation'}
# {'type': 'glossary', 'text': "annual bound statutes ( buckram bound, hardcover ) : annual bound statutes ( buckram bound, hardcover ) after the end of each calendar year, the king's printer publishes an official hardcover version of all new acts and amendment acts, both public and private, that were enacted during the year. in the case of private acts, the hardcover edition is likely the final publication, since most private acts are rarely consolidated or revised. the hardcover version includes a cumulative table of legislative changes. the annual statutes dating back to 1858 are available on bc laws.", 'chunkSeqId': 0, 'chunkId': 'glossary-Annual Bound Statutes (Buckram Bound, hardcover)-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Annual Bound Statutes (Buckram Bound, hardcover)'}
# {'type': 'glossary', 'text': "bill : a proposed law that is introduced to the legislative assembly for review and debate. a bill becomes an act ( law ) when it passes third reading. there are 3 types of bill : public bills ( generally deal with issues of significance for the whole province ) : a government bill is a public bill introduced by a minister of the government, which reflects government policy. a member's bill is a public bill introduced by an opposition mla, or a government mla who is not a minister. private bills ( generally deal with a specific issue affecting a person or group ) : a private bill is introduced by an mla on behalf of a person or a group outside the legislative assembly. when enacted they are called private, special or local acts.", 'chunkSeqId': 0, 'chunkId': 'glossary-Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Bill'}
# {'type': 'glossary', 'text': 'bill stages : a bill must pass through the following stages before it becomes law : first reading, second reading, committee, report, third reading, royal assent. not all bills complete the process.', 'chunkSeqId': 0, 'chunkId': 'glossary-Bill Stages-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Bill Stages'}
# {'type': 'glossary', 'text': 'cabinet : members of the governing party who have been appointed ministers ( heads of government ministries ). also called the executive council.', 'chunkSeqId': 0, 'chunkId': 'glossary-Cabinet-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Cabinet'}
# {'type': 'glossary', 'text': 'chapter numbers : when a bill becomes an act, as soon as it receives royal assent it is assigned a chapter number. the act is then cited by its chapter number and year of passage ; for example, the greenhouse gas reduction targets act, introduced as bill 17 of 2007, became chapter 42 of the statutes of british columbia 2007, and is cited as s. b. c. 2007, c. 42.', 'chunkSeqId': 0, 'chunkId': 'glossary-Chapter Numbers-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Chapter Numbers'}
# {'type': 'glossary', 'text': 'citation : the numerical reference for a statute or regulation ; for example, the citation for the adoption act is r. s. b. c. 1996, c. 5, which refers to chapter 5 of the revised statutes of british columbia of 1996. you may also come across citations in this format : 2002 - 12 - 25, which refers to the year of enactment, chapter number, and section number. the citation for the coal act regulation is b. c. reg 251 / 2004, which is the number assigned by the registrar of regulations when the regulation was deposited, and the year of deposit.', 'chunkSeqId': 0, 'chunkId': 'glossary-Citation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Citation'}
# {'type': 'glossary', 'text': 'coming into force : the time when an act or regulation takes effect and becomes the law. acts come into force on the date of royal assent, unless the act specifies otherwise in a commencement section. different provisions of the act may come into force on different dates. the commencement section details how the act or different provisions of the act are to come into force : either on a specified date, under specified circumstances, or by regulation. regulations usually come into force on the date of deposit, unless there is another date specified in the regulation.', 'chunkSeqId': 0, 'chunkId': 'glossary-Coming into force-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Coming into force'}
# {'type': 'glossary', 'text': 'commencement section : sometimes an act has a commencement section ( usually the last section in the act ) which details how and when the act ( or different provisions of the act ) comes into force. if there is no commencement section, the act comes into force on the date of royal assent.', 'chunkSeqId': 0, 'chunkId': 'glossary-Commencement Section-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Commencement Section'}
# {'type': 'glossary', 'text': 'committee : if a bill passes second reading it moves to the committee stage ( usually the committee of the whole house ) where it is debated provision by provision. at this stage amendments to a bill may be proposed. if a bill is amended it is usually reprinted for the report stage. if the bill is not amended it may go directly to third reading.', 'chunkSeqId': 0, 'chunkId': 'glossary-Committee-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Committee'}
# {'type': 'glossary', 'text': 'committee of the whole house : a committee, composed of all mlas, which debates a bill provision by provision.', 'chunkSeqId': 0, 'chunkId': 'glossary-Committee of the Whole House-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Committee of the Whole House'}
# {'type': 'glossary', 'text': 'consequential amendment : when an act is amended as a result of changes to - or the enactment of - another act, it is called a consequential amendment.', 'chunkSeqId': 0, 'chunkId': 'glossary-Consequential Amendment-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Consequential Amendment'}
# {'type': 'glossary', 'text': 'consolidated provisions in force : a complete, cross - referenced, alphabetical listing of acts passed during a particular sitting of the legislative assembly, includes the following information : act title, bill number, citation, which provisions of the bill affect the named act, whether the legislation comes into force on royal assent or by regulation, and the corresponding effective dates. the electronic listing is available on bc laws. this listing includes data from 1997 to january 2012.', 'chunkSeqId': 0, 'chunkId': 'glossary-Consolidated Provisions in Force-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Consolidated Provisions in Force'}
# {'type': 'glossary', 'text': "consolidated regulations of british columbia : the consolidated regulations were first published in 1981 in looseleaf format. the print publication has now transitioned to an online publication in portable document format ( pdf ) on bc laws. these unofficial online consolidations are provided for convenience only and are not prepared for the purposes of the evidence act. see also gazette ; historical note ; official version. to purchase official print consolidations contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': 'glossary-Consolidated Regulations of British Columbia-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Consolidated Regulations of British Columbia'}
# {'type': 'glossary', 'text': "consolidated statutes of british columbia ('the looseleaf') : at the end of each legislative session, all new public acts are consolidated and published by the king's printer in looseleaf format. the consolidation is assigned an'amendment'or'consolidation'number and cut - off date for publication. any amendments to existing acts, that are in force at the cut - off date, are included and are blended into the original text ( consolidated ). a table of legislative changes keeps track of the amendments, both those that are in force and those that are not in force at the cut - off date. often referred to as the'looseleaf'the consolidated statutes are formatted for insertion into the binder volumes of the most recent statute revision, so that the statutes may be kept up - to - date. see also official version. the electronic ( unofficial ) version of the consolidated statutes is available on bc laws. to purchase official print consolidations contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': "glossary-Consolidated Statutes of British Columbia ('the Looseleaf')-seq-0", 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': "Consolidated Statutes of British Columbia ('the Looseleaf')"}
# {'type': 'glossary', 'text': 'consolidation period : the period of time during which new material is incorporated into an instalment of the statutes and regulations. the date that accompanies each consolidation is the end date for that consolidation period, and serves as the cut - off date for publication.', 'chunkSeqId': 0, 'chunkId': 'glossary-Consolidation Period-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Consolidation Period'}
# {'type': 'glossary', 'text': 'corporate registry : includes corporate registry notices for company, extra - provincial company and societies filings such as amalgamations, change of name, continuations ( in and out ), dissolutions, incorporations, intent to cancel registrations, intent to dissolve, limited restorations, registrations cancelled, restorations. the company and extra - provincial company notices include data from january 2003 to present. the society notices include data from august 2011 to present. the corporate registry notices are available on bc laws.', 'chunkSeqId': 0, 'chunkId': 'glossary-Corporate Registry-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Corporate Registry'}
# {'type': 'glossary', 'text': 'current unofficial consolidation : a collection of all legislation currently in force in the province of british columbia, including an early look at new acts, regulations and amendments that have come into force since the last official consolidation was published. the current consolidation provides access to new legislation before the official print versions are available. the current consolidation is not an official version. see also consolidated statutes ; consolidated regulations ; official version. the current consolidations of statutes and regulations are published on bc laws.', 'chunkSeqId': 0, 'chunkId': 'glossary-Current Unofficial Consolidation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Current Unofficial Consolidation'}
# {'type': 'glossary', 'text': 'dissolution : dissolution ends a parliament. this is done by the lieutenant governor and is followed by a general election.', 'chunkSeqId': 0, 'chunkId': 'glossary-Dissolution-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Dissolution'}
# {'type': 'glossary', 'text': 'enact : a term used to describe the act of making a law.', 'chunkSeqId': 0, 'chunkId': 'glossary-Enact-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Enact'}
# {'type': 'glossary', 'text': 'executive council : see cabinet.', 'chunkSeqId': 0, 'chunkId': 'glossary-Executive Council-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Executive Council'}
# {'type': 'glossary', 'text': 'first reading : the introduction of a bill to the house is called first reading. the mla sponsoring the bill introduces the proposed law and explains its purpose. the bill is not debated at this time but mlas vote on whether to accept it for further debate. a second or third reading may follow.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'First Reading'}
# {'type': 'glossary', 'text': 'first reading bill : for its introduction of a bill into the house, a bill is printed in first reading format which includes explanatory notes about the purpose of the bill.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'First Reading Bill'}
# {'type': 'glossary', 'text': "gazette : the british columbia gazette is published by the king's printer under the authority of the king's printer act and the regulations act. part i of the gazette is published weekly and contains legal and official notices and proclamations. part ii is published every two weeks and contains the full text of all new regulations. print copies of the gazette are available from crown publications, king's printer. part i and ii of the gazette are also available on bc laws. gazette part i includes issues from january 2003 to present. gazette part ii includes issues from october 2001 to present.", 'chunkSeqId': 0, 'chunkId': 'glossary-Gazette-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Gazette'}
# {'type': 'glossary', 'text': "hansard : the verbatim transcript of what is said in the legislative assembly debates and in committees. print copies of hansard are available from crown publications, king's printer. hansard debates from march 17, 2002 to present are available on bc laws.", 'chunkSeqId': 0, 'chunkId': 'glossary-Hansard-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Hansard'}
# {'type': 'glossary', 'text': 'historical note : a note that follows a regulation section, detailing the enactment and amendment history of that section ; for example, [ en. b. c. reg. 327 / 96, s. 1 ; am. b. c. reg. 356 / 2000, s. 2. ] in this example, the regulation section was enacted by section 1 of regulation 327 / 96, and later amended by section 2 of regulation 356 / 2000.', 'chunkSeqId': 0, 'chunkId': 'glossary-Historical Note-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Historical Note'}
# {'type': 'glossary', 'text': 'historical supreme court rules : provides a full text of bc regulation 310 / 76 and bc regulation 221 / 90, as originally enacted. these two regulations were originally not reproduced in full within gazette part ii at the time they were enacted ; subsequent amendments to both regulations were gazetted.', 'chunkSeqId': 0, 'chunkId': 'glossary-Historical Supreme Court Rules-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Historical Supreme Court Rules'}
# {'type': 'glossary', 'text': "house : derived from the term house of assembly, the'house'is now used most frequently to describe the members ( mlas ) of the legislative assembly collectively.", 'chunkSeqId': 0, 'chunkId': 'glossary-House-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'House'}
# {'type': 'glossary', 'text': 'legislative assembly : all the elected members of the provincial legislative assembly ( mlas ) as a group, whether in government or opposition.', 'chunkSeqId': 0, 'chunkId': 'glossary-Legislative Assembly-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Legislative Assembly'}
# {'type': 'glossary', 'text': 'legislature : formally, the lieutenant governor acting by and with the advice and consent of the legislative assembly. the term is also commonly used to refer to the provincial parliament buildings which house the chamber where debates take place, the legislative library, and offices of staff and mlas.', 'chunkSeqId': 0, 'chunkId': 'glossary-Legislature-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Legislature'}
# {'type': 'glossary', 'text': "lieutenant governor : the queen's representative in each province of canada. the lieutenant governor ’ s approval ( royal assent ) is needed for a bill to become law.", 'chunkSeqId': 0, 'chunkId': 'glossary-Lieutenant Governor-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Lieutenant Governor'}
# {'type': 'glossary', 'text': 'lieutenant governor in council : the lieutenant governor acting by and with the advice and consent of the executive council.', 'chunkSeqId': 0, 'chunkId': 'glossary-Lieutenant Governor in Council-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Lieutenant Governor in Council'}
# {'type': 'glossary', 'text': 'looseleaf : see consolidated statutes ; official version.', 'chunkSeqId': 0, 'chunkId': 'glossary-Looseleaf-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Looseleaf'}
# {'type': 'glossary', 'text': 'minister of finance full - text directives and resumes : the minister of finance directives are issued under section 47 ( 1 ) of the financial administration act and are necessary to introduce or change fees when there is no other legislation available ; the fee is considered as a temporary measure ; the fee is authorized for cross - government purposes ; or there is a crisis or urgent situation. the resumes are summaries of the minister of finance directives and for informational purposes only. only available on bc laws. the documents include directives from 1983 to present.', 'chunkSeqId': 0, 'chunkId': 'glossary-Minister of Finance full-text Directives and Resumes-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Minister of Finance full-text Directives and Resumes'}
# {'type': 'glossary', 'text': 'mla : a member of the legislative assembly who is elected to represent, in the provincial parliament, the citizens of his or her riding.', 'chunkSeqId': 0, 'chunkId': 'glossary-MLA-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'MLA'}
# {'type': 'glossary', 'text': "motion : a proposal put to the legislative assembly framed in such a way as to seek the house's opinion or decision. a motion initiates all business undertaken by the house.", 'chunkSeqId': 0, 'chunkId': 'glossary-Motion-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Motion'}
# {'type': 'glossary', 'text': "official version :'official'versions of b. c.'s statutes and regulations are all printed by the king's printer and come in these formats : the annual bound statutes ; the british columbia gazette, part ii ; the consolidated statutes of b. c. ( looseleaf ), printed at the end of each legislative session ; the consolidated regulations of b. c. ( looseleaf ), printed every four months ( approximately ) ; individual consolidated statues and regulations. to purchase official versions contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': 'glossary-Official Version-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Official Version'}
# {'type': 'glossary', 'text': 'order, order in council, ministerial order : subordinate legislation made under the authority of a statute. orders may be made by the lieutenant governor in council, a minister, or an authorized official or body. orders are generally used to handle day - to - day administrative matters. while most orders are administrative in nature, some may be classed as regulations. published on bclaws.', 'chunkSeqId': 0, 'chunkId': 'glossary-Order, Order in Council, Ministerial Order-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Order, Order in Council, Ministerial Order'}
# {'type': 'glossary', 'text': 'parliament : the period between general elections composed of sessions that are made up of individual sittings in the house ; for example, the 36th parliament, 2nd session. also, a term commonly used to refer to the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Parliament-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Parliament'}
# {'type': 'glossary', 'text': 'point in time ( pit ) : tables linking users to an on - going list which shows how sections of an act or regulation read prior to an amendment or repeal. act pits from september 2000 and regulations pits from september 2009 are available on bclaws. regulation pits include the full text of regulations that may have ceased to have effect but have not been repealed and regulations that were not included in, or were removed from, the publication consolidated regulations of british columbia.', 'chunkSeqId': 0, 'chunkId': 'glossary-Point in Time (PIT)-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Point in Time (PIT)'}
# {'type': 'glossary', 'text': 'proclamation : proclamations by the lieutenant governor are used to convene, prorogue or dissolve the legislative assembly. proclamations are also used to give official support to an event or cause by declaring it ; for instance, earth day.', 'chunkSeqId': 0, 'chunkId': 'glossary-Proclamation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Proclamation'}
# {'type': 'glossary', 'text': 'prorogation : prorogation ends a parliamentary session, abolishing all pending business and halting all committee work.', 'chunkSeqId': 0, 'chunkId': 'glossary-Prorogation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Prorogation'}
# {'type': 'glossary', 'text': 'provision : a clause in a law specifying a particular condition or requirement.', 'chunkSeqId': 0, 'chunkId': 'glossary-Provision-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Provision'}
# {'type': 'glossary', 'text': 'provisions in force : a list of all acts affected ( enacted, amended or repealed ) during a session of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Provisions in Force-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Provisions in Force'}
# {'type': 'glossary', 'text': 'regulation : whereas an act provides the policy framework, the regulation ( s ) under the act provide the details to give effect to the policy. not all acts have regulations. sometimes regulations are used to bring acts into force.', 'chunkSeqId': 0, 'chunkId': 'glossary-Regulation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Regulation'}
# {'type': 'glossary', 'text': 'regulations bulletins : a summary of all regulations deposited with the registrar of regulations during a given period ( usually a week ). the cumulative bulletin lists all regulations deposited during a calendar year.', 'chunkSeqId': 0, 'chunkId': 'glossary-Regulations Bulletins-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Regulations Bulletins'}
# {'type': 'glossary', 'text': 'repealed : when laws are repealed they are no longer in force. statutes and regulations can be repealed ; repealed and replaced by another statute or regulation with a different title ; or renamed. they can also have built - in expiry provisions, or be enacted for a specific period, after which they are considered to be spent without the need for repeal. if the act under which a regulation is authorized is no longer in force the regulation expires, unless a replacement act with similar authority takes its place.', 'chunkSeqId': 0, 'chunkId': 'glossary-Repealed-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Repealed'}
# {'type': 'glossary', 'text': "report bill : if a bill has been amended during committee debate it is reprinted in a version which highlights the changes and has the heading'for report '. this version is referred to as a report bill or an amended bill. the bill can then be presented for third reading.", 'chunkSeqId': 0, 'chunkId': 'glossary-Report Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Report Bill'}
# {'type': 'glossary', 'text': "revision : periodically ( every 10 to 20 years in b. c. ) the public statutes are revised, primarily to consolidate amendments, simplify the numbering, reorganize the content and update the language. the most recent revision was published in 1996 and is referred to as the revised statutes of british columbia, 1996 ( r. s. b. c. 1996 ). the 1996 revision contains all public acts that were in force on december 31, 1996, as they appeared on that day. the official print version of the 1996 statute revision is available from crown publications, king's printer. the 1996 revision is also available on bc laws.", 'chunkSeqId': 0, 'chunkId': 'glossary-Revision-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Revision'}
# {'type': 'glossary', 'text': 'royal assent : after a bill has passed third reading in the legislative assembly, the lieutenant governor, on behalf of the queen, assents to the bill by signing it. the bill is thereby enacted and becomes an act, i. e. a law. unless an act contains a stated effective date, or a provision requiring that it be brought into force by regulation, it comes into force on the day royal assent is given.', 'chunkSeqId': 0, 'chunkId': 'glossary-Royal Assent-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Royal Assent'}
# {'type': 'glossary', 'text': 'r. s. b. c. : the abbreviation for the revised statutes of british columbia. the citation r. s. b. c. 1996, c. 22 indicates the statute was revised and republished as chapter 22 of the 1996 revision. the revised statutes of 1996 stated the law as of december 31, 1996.', 'chunkSeqId': 0, 'chunkId': 'glossary-R.S.B.C.-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'R.S.B.C.'}
# {'type': 'glossary', 'text': 's. b. c. : the abbreviation for the statutes of british columbia. the citation s. b. c. 2003 c. 25 indicates chapter 25 of the statutes enacted in 2003.', 'chunkSeqId': 0, 'chunkId': 'glossary-S.B.C.-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'S.B.C.'}
# {'type': 'glossary', 'text': 'second reading : at second reading members of the legislative assembly debate a bill ’ s general principles and goals. if the bill passes second reading it moves to the committee stage where it is debated provision by provision.', 'chunkSeqId': 0, 'chunkId': 'glossary-Second Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Second Reading'}
# {'type': 'glossary', 'text': 'session : a session is made up of a series of sittings of the legislative assembly during a parliament. a session begins with the speech from the throne and ends with prorogation or dissolution. at least one session of the legislative assembly is held each year.', 'chunkSeqId': 0, 'chunkId': 'glossary-Session-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Session'}
# {'type': 'glossary', 'text': 'sitting : a meeting of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Sitting-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Sitting'}
# {'type': 'glossary', 'text': 'source law : statutes as originally enacted by the legislative assembly ; and regulations as filed or deposited with the registrar of regulations.', 'chunkSeqId': 0, 'chunkId': 'glossary-Source Law-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Source Law'}
# {'type': 'glossary', 'text': 'statute : also called an act.', 'chunkSeqId': 0, 'chunkId': 'glossary-Statute-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Statute'}
# {'type': 'glossary', 'text': 'supplement : when a statute revision is done, supplements are created to keep track of any amendments to acts that were enacted but not in force on the cut - off date for the revision. supplements not in force on december 31, 1996 ; the date of the last statue revision are published on bc laws.', 'chunkSeqId': 0, 'chunkId': 'glossary-Supplement-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Supplement'}
# {'type': 'glossary', 'text': "table of legislative changes : this table identifies'changes not in force'and'changes in force'of an act. the table includes the section of the act affected by changes ; the nature of these changes ; the enactment making the changes ;'changes not in force ', and also, how the changes are to come into force. the first edition ( january 1, 1997 to december 31, 2004 ) and second edition ( january 1, 2005 to present ) table of legislative changes ( tlcs ) are published on bclaws. prior to the statue revision the historical table provided similar information as the table of legislative chances for acts from 1979 to the 1996 revision. historical tables are also available on bclaws.", 'chunkSeqId': 0, 'chunkId': 'glossary-Table of Legislative Changes-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Table of Legislative Changes'}
# {'type': 'glossary', 'text': 'table of statutes - repealed, replaced and renamed : this table assists with tracking outdated legislation. it covers public statutes since 1897 to april 2011 that have been repealed and not replaced ; repealed and replaced by a statute with a different title ; or statutes that have been retitled either by amendment of the legislature or during revision.', 'chunkSeqId': 0, 'chunkId': 'glossary-Table of Statutes - Repealed, Replaced and Renamed-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Table of Statutes - Repealed, Replaced and Renamed'}
# {'type': 'glossary', 'text': 'third reading : third reading is the final opportunity for the legislative assembly to debate a bill before a final vote is taken on whether to pass it, although the bill is not usually debated at this stage. once a bill has passed third reading the speaker announces that it is an act of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Third Reading'}
# {'type': 'glossary', 'text': 'third reading bill : a bill that has been voted on and passed by the legislative assembly with or without amendment. once the bill has passed third reading it is certified correct by the law clerk before being printed.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm': 'Third Reading Bill'}

# %% [markdown]
# ## Now that we have index all the glossary we now need to attach the references

# %%
connect_chunks = """
      MATCH (chunk:UpdatedChunk), (f:UpdatedChunk)
      WHERE
        chunk.chunkId = $chunkParam.chunkId
        AND chunk.chunkSeqId = $chunkParam.chunkSeqId
        AND chunk.text = $chunkParam.text
        AND chunk.glossaryTerm = $chunkParam.glossaryTerm1
        AND chunk.type = $chunkParam.type
        AND f.type = $chunkParam.type
        AND f.glossaryTerm = $chunkParam.glossaryTerm2
        AND f.chunkId = $chunkParam.chunkId2
        AND f.chunkSeqId = 0
      MERGE (chunk)-[newRelationship:RELATED_TERMS]->(f)
      RETURN count(newRelationship)
    """

# %%
for glossary in enumerate(glossaries['terms']):
    text = glossary[1]['term'] + ': ' + glossary[1]['description']
    #print(item_text_chunks)
    token_split_texts = []
    data_type = 'glossary'
    # Validate if all the text fits into the 256 token size to create the embeddings
    token_split_texts += token_splitter.split_text(text)
    for chunk_seq, token in enumerate(token_split_texts):
        for glossary_terms in glossary[1]['related_terms']:
            chunk = {
                'type': data_type,
                'text': token,
                'chunkSeqId': chunk_seq,
                'chunkId': f'{data_type}-{glossary[1]["term"]}-seq-{str(chunk_seq)}',
                'url': 'https://www.bclaws.gov.bc.ca/glossary.html',
                'glossaryTerm1': glossary[1]['term'],
                'glossaryTerm2': glossary_terms,
                'chunkId2': f'{data_type}-{glossary_terms}-seq-0'
            }
            print(chunk)
            ret = kg.query(connect_chunks, 
            params={
                'chunkParam': chunk
            })
            print(ret)
            print('\n\n')
# Out:
# {'type': 'glossary', 'text': 'act : also called a statute. when a bill ( proposed law ) passes third reading in the legislative assembly, and receives royal assent, it is thereby enacted and becomes an act or law. public statutes generally deal with issues of significance for the whole province. private, local and special statutes are enacted by the legislature on behalf of a person, a group, a municipality or a corporation, and affect only the interests of that person or group.', 'chunkSeqId': 0, 'chunkId': 'glossary-Act-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Act', 'glossaryTerm2': 'Bill', 'chunkId2': 'glossary-Bill-seq-0'}
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:610, in BoltSocket._handshake(cls, s, resolved_address, deadline)
#     609     s.sendall(request)
# --> 610     response = s.recv(4)
#     611 except OSError as exc:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:694, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     692     s = BoltSocket._secure(s, resolved_address._host_name,
#     693                            ssl_context)
# --> 694     return BoltSocket._handshake(s, resolved_address, deadline)
#     695 except (BoltError, DriverError, OSError) as error:
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:612, in BoltSocket._handshake(cls, s, resolved_address, deadline)
#     611 except OSError as exc:
# --> 612     raise ServiceUnavailable(
#     613         f"Failed to read any data from server {resolved_address!r} "
#     614         f"after connected (deadline {deadline})"
#     615     ) from exc
#     616 finally:
#
# ServiceUnavailable: Failed to read any data from server ResolvedIPv6Address(('::1', 7687, 0, 0)) after connected (deadline Deadline(timeout=60.0))
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[55], line 21
#      10 chunk = {
#      11     'type': data_type,
#      12     'text': token,
#    (...)
#      18     'chunkId2': f'{data_type}-{glossary_terms}-seq-0'
#      19 }
#      20 print(chunk)
# ---> 21 ret = kg.query(connect_chunks,
#      22 params={
#      23     'chunkParam': chunk
#      24 })
#      25 print(ret)
#      26 print('\n\n')
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_community/graphs/neo4j_graph.py:419, in Neo4jGraph.query(self, query, params)
#     417 with self._driver.session(database=self._database) as session:
#     418     try:
# --> 419         data = session.run(Query(text=query, timeout=self.timeout), params)
#     420         json_data = [r.data() for r in data]
#     421         if self.sanitize:
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_sync/work/session.py:302, in Session.run(self, query, parameters, **kwargs)
#     299     self._auto_result._buffer_all()
#     301 if not self._connection:
# --> 302     self._connect(self._config.default_access_mode)
#     303     assert self._connection is not None
#     304 cx = self._connection
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:182, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
# --> 182 self._connection = self._pool.acquire(**acquire_kwargs_)
#     183 self._connection_access_mode = access_mode
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:526, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     523 log.debug("[#0000]  _: <POOL> acquire direct connection, "
#     524           "access_mode=%r, database=%r", access_mode, database)
#     525 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 526 return self._acquire(
#     527     self.address, auth, deadline, liveness_check_timeout
#     528 )
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:313, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     308             raise ClientError(
#     309                 "failed to obtain a connection from the pool within "
#     310                 "{!r}s (timeout)".format(deadline.original_timeout)
#     311             )
#     312 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 313 return connection_creator()
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:163, in IOPool._acquire_new_later.<locals>.connection_creator()
#     161 try:
#     162     try:
# --> 163         connection = self.opener(
#     164             address, auth or self.pool_config.auth, deadline
#     165         )
#     166     except ServiceUnavailable:
#     167         self.deactivate(address)
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:500, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     499 def opener(addr, auth_manager, deadline):
# --> 500     return Bolt.open(
#     501         addr, auth_manager=auth_manager, deadline=deadline,
#     502         routing_context=None, pool_config=pool_config
#     503     )
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:403, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     399 if deadline is None:
#     400     deadline = Deadline(None)
#     402 s, protocol_version, handshake, data = \
# --> 403     BoltSocket.connect(
#     404         address,
#     405         tcp_timeout=pool_config.connection_timeout,
#     406         deadline=deadline,
#     407         custom_resolver=pool_config.resolver,
#     408         ssl_context=pool_config.get_ssl_context(),
#     409         keep_alive=pool_config.keep_alive,
#     410     )
#     412 pool_config.protocol_version = protocol_version
#     414 # Carry out Bolt subclass imports locally to avoid circular dependency
#     415 # issues.
#
# File ~/miniconda3/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:718, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     713     raise ServiceUnavailable(
#     714         "Couldn't connect to %s (resolved to %s)" % (
#     715             str(address), tuple(map(str, resolved_addresses)))
#     716     )
#     717 else:
# --> 718     raise ServiceUnavailable(
#     719         "Couldn't connect to %s (resolved to %s):\n%s" % (
#     720             str(address), tuple(map(str, resolved_addresses)),
#     721             "\n".join(map(str, errors))
#     722         )
#     723     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ()):
# Failed to read any data from server ResolvedIPv6Address(('::1', 7687, 0, 0)) after connected (deadline Deadline(timeout=60.0))
# Failed to read any data from server ResolvedIPv4Address(('127.0.0.1', 7687)) after connected (deadline Deadline(timeout=60.0))

# %%
for idx, glossary in enumerate(glossaries['terms']):
    text = glossary['term'] + ': ' + glossary['description']
    token_split_texts = []
    data_type = 'glossary'
    
    # Split text into chunks fitting the 256 token size
    token_split_texts += token_splitter.split_text(text)
    
    for chunk_seq, token in enumerate(token_split_texts):
        for glossary_term in glossary['related_terms']:
            chunk = {
                'type': data_type,
                'text': token,
                'chunkSeqId': chunk_seq,
                'chunkId': f'{data_type}-{glossary["term"]}-seq-{chunk_seq}',
                'url': 'https://www.bclaws.gov.bc.ca/glossary.html',
                'glossaryTerm1': glossary['term'],
                'glossaryTerm2': glossary_term,
                'chunkId2': f'{data_type}-{glossary_term}-seq-0'  # Assuming seq-0 for related terms
            }
            
            # Execute the query with the current chunk parameters
            ret = kg.query(connect_chunks, params={'chunkParam': chunk})
            print(chunk)
            print(ret)
            print('\n\n')
# Out:
# {'type': 'glossary', 'text': 'act : also called a statute. when a bill ( proposed law ) passes third reading in the legislative assembly, and receives royal assent, it is thereby enacted and becomes an act or law. public statutes generally deal with issues of significance for the whole province. private, local and special statutes are enacted by the legislature on behalf of a person, a group, a municipality or a corporation, and affect only the interests of that person or group.', 'chunkSeqId': 0, 'chunkId': 'glossary-Act-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Act', 'glossaryTerm2': 'Bill', 'chunkId2': 'glossary-Bill-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'act : also called a statute. when a bill ( proposed law ) passes third reading in the legislative assembly, and receives royal assent, it is thereby enacted and becomes an act or law. public statutes generally deal with issues of significance for the whole province. private, local and special statutes are enacted by the legislature on behalf of a person, a group, a municipality or a corporation, and affect only the interests of that person or group.', 'chunkSeqId': 0, 'chunkId': 'glossary-Act-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Act', 'glossaryTerm2': 'Regulation', 'chunkId2': 'glossary-Regulation-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'adjournment : an adjournment temporarily ends a sitting or a session. all business not concluded at the time of adjournment is resumed at the next sitting or session.', 'chunkSeqId': 0, 'chunkId': 'glossary-Adjournment-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Adjournment', 'glossaryTerm2': 'Dissolution', 'chunkId2': 'glossary-Dissolution-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'adjournment : an adjournment temporarily ends a sitting or a session. all business not concluded at the time of adjournment is resumed at the next sitting or session.', 'chunkSeqId': 0, 'chunkId': 'glossary-Adjournment-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Adjournment', 'glossaryTerm2': 'Prorogation', 'chunkId2': 'glossary-Prorogation-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'amended bill : see report bill.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amended Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Amended Bill', 'glossaryTerm2': 'Report Bill', 'chunkId2': 'glossary-Report Bill-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'amending bill : a bill that proposes to amend an existing act by adding, removing or substituting text in the existing act.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amending Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Amending Bill', 'glossaryTerm2': 'Bill', 'chunkId2': 'glossary-Bill-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'amending bill : a bill that proposes to amend an existing act by adding, removing or substituting text in the existing act.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amending Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Amending Bill', 'glossaryTerm2': 'Act', 'chunkId2': 'glossary-Act-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'amending regulation : a regulation that amends an existing regulation or act by adding, removing or substituting text.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amending Regulation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Amending Regulation', 'glossaryTerm2': 'Regulation', 'chunkId2': 'glossary-Regulation-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'amending regulation : a regulation that amends an existing regulation or act by adding, removing or substituting text.', 'chunkSeqId': 0, 'chunkId': 'glossary-Amending Regulation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Amending Regulation', 'glossaryTerm2': 'Act', 'chunkId2': 'glossary-Act-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': "annual bound statutes ( buckram bound, hardcover ) : annual bound statutes ( buckram bound, hardcover ) after the end of each calendar year, the king's printer publishes an official hardcover version of all new acts and amendment acts, both public and private, that were enacted during the year. in the case of private acts, the hardcover edition is likely the final publication, since most private acts are rarely consolidated or revised. the hardcover version includes a cumulative table of legislative changes. the annual statutes dating back to 1858 are available on bc laws.", 'chunkSeqId': 0, 'chunkId': 'glossary-Annual Bound Statutes (Buckram Bound, hardcover)-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Annual Bound Statutes (Buckram Bound, hardcover)', 'glossaryTerm2': 'Consolidated Statutes', 'chunkId2': 'glossary-Consolidated Statutes-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "annual bound statutes ( buckram bound, hardcover ) : annual bound statutes ( buckram bound, hardcover ) after the end of each calendar year, the king's printer publishes an official hardcover version of all new acts and amendment acts, both public and private, that were enacted during the year. in the case of private acts, the hardcover edition is likely the final publication, since most private acts are rarely consolidated or revised. the hardcover version includes a cumulative table of legislative changes. the annual statutes dating back to 1858 are available on bc laws.", 'chunkSeqId': 0, 'chunkId': 'glossary-Annual Bound Statutes (Buckram Bound, hardcover)-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Annual Bound Statutes (Buckram Bound, hardcover)', 'glossaryTerm2': 'Official Version', 'chunkId2': 'glossary-Official Version-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "bill : a proposed law that is introduced to the legislative assembly for review and debate. a bill becomes an act ( law ) when it passes third reading. there are 3 types of bill : public bills ( generally deal with issues of significance for the whole province ) : a government bill is a public bill introduced by a minister of the government, which reflects government policy. a member's bill is a public bill introduced by an opposition mla, or a government mla who is not a minister. private bills ( generally deal with a specific issue affecting a person or group ) : a private bill is introduced by an mla on behalf of a person or a group outside the legislative assembly. when enacted they are called private, special or local acts.", 'chunkSeqId': 0, 'chunkId': 'glossary-Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Bill', 'glossaryTerm2': 'Bill Stages', 'chunkId2': 'glossary-Bill Stages-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': "bill : a proposed law that is introduced to the legislative assembly for review and debate. a bill becomes an act ( law ) when it passes third reading. there are 3 types of bill : public bills ( generally deal with issues of significance for the whole province ) : a government bill is a public bill introduced by a minister of the government, which reflects government policy. a member's bill is a public bill introduced by an opposition mla, or a government mla who is not a minister. private bills ( generally deal with a specific issue affecting a person or group ) : a private bill is introduced by an mla on behalf of a person or a group outside the legislative assembly. when enacted they are called private, special or local acts.", 'chunkSeqId': 0, 'chunkId': 'glossary-Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Bill', 'glossaryTerm2': 'First Reading', 'chunkId2': 'glossary-First Reading-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': "bill : a proposed law that is introduced to the legislative assembly for review and debate. a bill becomes an act ( law ) when it passes third reading. there are 3 types of bill : public bills ( generally deal with issues of significance for the whole province ) : a government bill is a public bill introduced by a minister of the government, which reflects government policy. a member's bill is a public bill introduced by an opposition mla, or a government mla who is not a minister. private bills ( generally deal with a specific issue affecting a person or group ) : a private bill is introduced by an mla on behalf of a person or a group outside the legislative assembly. when enacted they are called private, special or local acts.", 'chunkSeqId': 0, 'chunkId': 'glossary-Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Bill', 'glossaryTerm2': 'Second Reading', 'chunkId2': 'glossary-Second Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "bill : a proposed law that is introduced to the legislative assembly for review and debate. a bill becomes an act ( law ) when it passes third reading. there are 3 types of bill : public bills ( generally deal with issues of significance for the whole province ) : a government bill is a public bill introduced by a minister of the government, which reflects government policy. a member's bill is a public bill introduced by an opposition mla, or a government mla who is not a minister. private bills ( generally deal with a specific issue affecting a person or group ) : a private bill is introduced by an mla on behalf of a person or a group outside the legislative assembly. when enacted they are called private, special or local acts.", 'chunkSeqId': 0, 'chunkId': 'glossary-Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Bill', 'glossaryTerm2': 'Third Reading', 'chunkId2': 'glossary-Third Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'bill stages : a bill must pass through the following stages before it becomes law : first reading, second reading, committee, report, third reading, royal assent. not all bills complete the process.', 'chunkSeqId': 0, 'chunkId': 'glossary-Bill Stages-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Bill Stages', 'glossaryTerm2': 'Bill', 'chunkId2': 'glossary-Bill-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'bill stages : a bill must pass through the following stages before it becomes law : first reading, second reading, committee, report, third reading, royal assent. not all bills complete the process.', 'chunkSeqId': 0, 'chunkId': 'glossary-Bill Stages-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Bill Stages', 'glossaryTerm2': 'First Reading', 'chunkId2': 'glossary-First Reading-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'bill stages : a bill must pass through the following stages before it becomes law : first reading, second reading, committee, report, third reading, royal assent. not all bills complete the process.', 'chunkSeqId': 0, 'chunkId': 'glossary-Bill Stages-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Bill Stages', 'glossaryTerm2': 'Second Reading', 'chunkId2': 'glossary-Second Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'bill stages : a bill must pass through the following stages before it becomes law : first reading, second reading, committee, report, third reading, royal assent. not all bills complete the process.', 'chunkSeqId': 0, 'chunkId': 'glossary-Bill Stages-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Bill Stages', 'glossaryTerm2': 'Third Reading', 'chunkId2': 'glossary-Third Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'cabinet : members of the governing party who have been appointed ministers ( heads of government ministries ). also called the executive council.', 'chunkSeqId': 0, 'chunkId': 'glossary-Cabinet-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Cabinet', 'glossaryTerm2': 'Executive Council', 'chunkId2': 'glossary-Executive Council-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'chapter numbers : when a bill becomes an act, as soon as it receives royal assent it is assigned a chapter number. the act is then cited by its chapter number and year of passage ; for example, the greenhouse gas reduction targets act, introduced as bill 17 of 2007, became chapter 42 of the statutes of british columbia 2007, and is cited as s. b. c. 2007, c. 42.', 'chunkSeqId': 0, 'chunkId': 'glossary-Chapter Numbers-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Chapter Numbers', 'glossaryTerm2': 'Bill', 'chunkId2': 'glossary-Bill-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'chapter numbers : when a bill becomes an act, as soon as it receives royal assent it is assigned a chapter number. the act is then cited by its chapter number and year of passage ; for example, the greenhouse gas reduction targets act, introduced as bill 17 of 2007, became chapter 42 of the statutes of british columbia 2007, and is cited as s. b. c. 2007, c. 42.', 'chunkSeqId': 0, 'chunkId': 'glossary-Chapter Numbers-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Chapter Numbers', 'glossaryTerm2': 'Act', 'chunkId2': 'glossary-Act-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'coming into force : the time when an act or regulation takes effect and becomes the law. acts come into force on the date of royal assent, unless the act specifies otherwise in a commencement section. different provisions of the act may come into force on different dates. the commencement section details how the act or different provisions of the act are to come into force : either on a specified date, under specified circumstances, or by regulation. regulations usually come into force on the date of deposit, unless there is another date specified in the regulation.', 'chunkSeqId': 0, 'chunkId': 'glossary-Coming into force-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Coming into force', 'glossaryTerm2': 'Royal Assent', 'chunkId2': 'glossary-Royal Assent-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'commencement section : sometimes an act has a commencement section ( usually the last section in the act ) which details how and when the act ( or different provisions of the act ) comes into force. if there is no commencement section, the act comes into force on the date of royal assent.', 'chunkSeqId': 0, 'chunkId': 'glossary-Commencement Section-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Commencement Section', 'glossaryTerm2': 'Royal Assent', 'chunkId2': 'glossary-Royal Assent-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'committee : if a bill passes second reading it moves to the committee stage ( usually the committee of the whole house ) where it is debated provision by provision. at this stage amendments to a bill may be proposed. if a bill is amended it is usually reprinted for the report stage. if the bill is not amended it may go directly to third reading.', 'chunkSeqId': 0, 'chunkId': 'glossary-Committee-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Committee', 'glossaryTerm2': 'Committee of the Whole House', 'chunkId2': 'glossary-Committee of the Whole House-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'committee of the whole house : a committee, composed of all mlas, which debates a bill provision by provision.', 'chunkSeqId': 0, 'chunkId': 'glossary-Committee of the Whole House-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Committee of the Whole House', 'glossaryTerm2': 'Committee', 'chunkId2': 'glossary-Committee-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'consequential amendment : when an act is amended as a result of changes to - or the enactment of - another act, it is called a consequential amendment.', 'chunkSeqId': 0, 'chunkId': 'glossary-Consequential Amendment-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Consequential Amendment', 'glossaryTerm2': 'Amendment', 'chunkId2': 'glossary-Amendment-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': "consolidated regulations of british columbia : the consolidated regulations were first published in 1981 in looseleaf format. the print publication has now transitioned to an online publication in portable document format ( pdf ) on bc laws. these unofficial online consolidations are provided for convenience only and are not prepared for the purposes of the evidence act. see also gazette ; historical note ; official version. to purchase official print consolidations contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': 'glossary-Consolidated Regulations of British Columbia-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Consolidated Regulations of British Columbia', 'glossaryTerm2': 'Gazette', 'chunkId2': 'glossary-Gazette-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': "consolidated regulations of british columbia : the consolidated regulations were first published in 1981 in looseleaf format. the print publication has now transitioned to an online publication in portable document format ( pdf ) on bc laws. these unofficial online consolidations are provided for convenience only and are not prepared for the purposes of the evidence act. see also gazette ; historical note ; official version. to purchase official print consolidations contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': 'glossary-Consolidated Regulations of British Columbia-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Consolidated Regulations of British Columbia', 'glossaryTerm2': 'Historical Note', 'chunkId2': 'glossary-Historical Note-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': "consolidated regulations of british columbia : the consolidated regulations were first published in 1981 in looseleaf format. the print publication has now transitioned to an online publication in portable document format ( pdf ) on bc laws. these unofficial online consolidations are provided for convenience only and are not prepared for the purposes of the evidence act. see also gazette ; historical note ; official version. to purchase official print consolidations contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': 'glossary-Consolidated Regulations of British Columbia-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Consolidated Regulations of British Columbia', 'glossaryTerm2': 'Official Version', 'chunkId2': 'glossary-Official Version-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "consolidated statutes of british columbia ('the looseleaf') : at the end of each legislative session, all new public acts are consolidated and published by the king's printer in looseleaf format. the consolidation is assigned an'amendment'or'consolidation'number and cut - off date for publication. any amendments to existing acts, that are in force at the cut - off date, are included and are blended into the original text ( consolidated ). a table of legislative changes keeps track of the amendments, both those that are in force and those that are not in force at the cut - off date. often referred to as the'looseleaf'the consolidated statutes are formatted for insertion into the binder volumes of the most recent statute revision, so that the statutes may be kept up - to - date. see also official version. the electronic ( unofficial ) version of the consolidated statutes is available on bc laws. to purchase official print consolidations contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': "glossary-Consolidated Statutes of British Columbia ('the Looseleaf')-seq-0", 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': "Consolidated Statutes of British Columbia ('the Looseleaf')", 'glossaryTerm2': 'Official Version', 'chunkId2': 'glossary-Official Version-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'current unofficial consolidation : a collection of all legislation currently in force in the province of british columbia, including an early look at new acts, regulations and amendments that have come into force since the last official consolidation was published. the current consolidation provides access to new legislation before the official print versions are available. the current consolidation is not an official version. see also consolidated statutes ; consolidated regulations ; official version. the current consolidations of statutes and regulations are published on bc laws.', 'chunkSeqId': 0, 'chunkId': 'glossary-Current Unofficial Consolidation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Current Unofficial Consolidation', 'glossaryTerm2': 'Consolidated Statutes', 'chunkId2': 'glossary-Consolidated Statutes-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'current unofficial consolidation : a collection of all legislation currently in force in the province of british columbia, including an early look at new acts, regulations and amendments that have come into force since the last official consolidation was published. the current consolidation provides access to new legislation before the official print versions are available. the current consolidation is not an official version. see also consolidated statutes ; consolidated regulations ; official version. the current consolidations of statutes and regulations are published on bc laws.', 'chunkSeqId': 0, 'chunkId': 'glossary-Current Unofficial Consolidation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Current Unofficial Consolidation', 'glossaryTerm2': 'Consolidated Regulations', 'chunkId2': 'glossary-Consolidated Regulations-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'current unofficial consolidation : a collection of all legislation currently in force in the province of british columbia, including an early look at new acts, regulations and amendments that have come into force since the last official consolidation was published. the current consolidation provides access to new legislation before the official print versions are available. the current consolidation is not an official version. see also consolidated statutes ; consolidated regulations ; official version. the current consolidations of statutes and regulations are published on bc laws.', 'chunkSeqId': 0, 'chunkId': 'glossary-Current Unofficial Consolidation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Current Unofficial Consolidation', 'glossaryTerm2': 'Official Version', 'chunkId2': 'glossary-Official Version-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'dissolution : dissolution ends a parliament. this is done by the lieutenant governor and is followed by a general election.', 'chunkSeqId': 0, 'chunkId': 'glossary-Dissolution-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Dissolution', 'glossaryTerm2': 'Adjournment', 'chunkId2': 'glossary-Adjournment-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'dissolution : dissolution ends a parliament. this is done by the lieutenant governor and is followed by a general election.', 'chunkSeqId': 0, 'chunkId': 'glossary-Dissolution-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Dissolution', 'glossaryTerm2': 'Prorogation', 'chunkId2': 'glossary-Prorogation-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'executive council : see cabinet.', 'chunkSeqId': 0, 'chunkId': 'glossary-Executive Council-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Executive Council', 'glossaryTerm2': 'Cabinet', 'chunkId2': 'glossary-Cabinet-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'first reading : the introduction of a bill to the house is called first reading. the mla sponsoring the bill introduces the proposed law and explains its purpose. the bill is not debated at this time but mlas vote on whether to accept it for further debate. a second or third reading may follow.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'First Reading', 'glossaryTerm2': 'Bill Stages', 'chunkId2': 'glossary-Bill Stages-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'first reading : the introduction of a bill to the house is called first reading. the mla sponsoring the bill introduces the proposed law and explains its purpose. the bill is not debated at this time but mlas vote on whether to accept it for further debate. a second or third reading may follow.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'First Reading', 'glossaryTerm2': 'Committee', 'chunkId2': 'glossary-Committee-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'first reading : the introduction of a bill to the house is called first reading. the mla sponsoring the bill introduces the proposed law and explains its purpose. the bill is not debated at this time but mlas vote on whether to accept it for further debate. a second or third reading may follow.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'First Reading', 'glossaryTerm2': 'Second Reading', 'chunkId2': 'glossary-Second Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'first reading : the introduction of a bill to the house is called first reading. the mla sponsoring the bill introduces the proposed law and explains its purpose. the bill is not debated at this time but mlas vote on whether to accept it for further debate. a second or third reading may follow.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'First Reading', 'glossaryTerm2': 'Third Reading', 'chunkId2': 'glossary-Third Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'first reading bill : for its introduction of a bill into the house, a bill is printed in first reading format which includes explanatory notes about the purpose of the bill.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'First Reading Bill', 'glossaryTerm2': 'Bill Stages', 'chunkId2': 'glossary-Bill Stages-seq-0'}
# [{'count(newRelationship)': 1}]
#
#
#
# {'type': 'glossary', 'text': 'first reading bill : for its introduction of a bill into the house, a bill is printed in first reading format which includes explanatory notes about the purpose of the bill.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'First Reading Bill', 'glossaryTerm2': 'Report Bill', 'chunkId2': 'glossary-Report Bill-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'first reading bill : for its introduction of a bill into the house, a bill is printed in first reading format which includes explanatory notes about the purpose of the bill.', 'chunkSeqId': 0, 'chunkId': 'glossary-First Reading Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'First Reading Bill', 'glossaryTerm2': 'Third Reading Bill', 'chunkId2': 'glossary-Third Reading Bill-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'looseleaf : see consolidated statutes ; official version.', 'chunkSeqId': 0, 'chunkId': 'glossary-Looseleaf-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Looseleaf', 'glossaryTerm2': 'Consolidated Statutes', 'chunkId2': 'glossary-Consolidated Statutes-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'looseleaf : see consolidated statutes ; official version.', 'chunkSeqId': 0, 'chunkId': 'glossary-Looseleaf-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Looseleaf', 'glossaryTerm2': 'Official Version', 'chunkId2': 'glossary-Official Version-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "official version :'official'versions of b. c.'s statutes and regulations are all printed by the king's printer and come in these formats : the annual bound statutes ; the british columbia gazette, part ii ; the consolidated statutes of b. c. ( looseleaf ), printed at the end of each legislative session ; the consolidated regulations of b. c. ( looseleaf ), printed every four months ( approximately ) ; individual consolidated statues and regulations. to purchase official versions contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': 'glossary-Official Version-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Official Version', 'glossaryTerm2': 'Annual Bound Statutes', 'chunkId2': 'glossary-Annual Bound Statutes-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "official version :'official'versions of b. c.'s statutes and regulations are all printed by the king's printer and come in these formats : the annual bound statutes ; the british columbia gazette, part ii ; the consolidated statutes of b. c. ( looseleaf ), printed at the end of each legislative session ; the consolidated regulations of b. c. ( looseleaf ), printed every four months ( approximately ) ; individual consolidated statues and regulations. to purchase official versions contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': 'glossary-Official Version-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Official Version', 'glossaryTerm2': 'Consolidated Statutes', 'chunkId2': 'glossary-Consolidated Statutes-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "official version :'official'versions of b. c.'s statutes and regulations are all printed by the king's printer and come in these formats : the annual bound statutes ; the british columbia gazette, part ii ; the consolidated statutes of b. c. ( looseleaf ), printed at the end of each legislative session ; the consolidated regulations of b. c. ( looseleaf ), printed every four months ( approximately ) ; individual consolidated statues and regulations. to purchase official versions contact crown publications, king's printer.", 'chunkSeqId': 0, 'chunkId': 'glossary-Official Version-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Official Version', 'glossaryTerm2': 'Consolidated Regulations', 'chunkId2': 'glossary-Consolidated Regulations-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'prorogation : prorogation ends a parliamentary session, abolishing all pending business and halting all committee work.', 'chunkSeqId': 0, 'chunkId': 'glossary-Prorogation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Prorogation', 'glossaryTerm2': 'Adjournment', 'chunkId2': 'glossary-Adjournment-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'prorogation : prorogation ends a parliamentary session, abolishing all pending business and halting all committee work.', 'chunkSeqId': 0, 'chunkId': 'glossary-Prorogation-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Prorogation', 'glossaryTerm2': 'Dissolution', 'chunkId2': 'glossary-Dissolution-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'provisions in force : a list of all acts affected ( enacted, amended or repealed ) during a session of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Provisions in Force-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Provisions in Force', 'glossaryTerm2': 'Consolidated Provisions in Force', 'chunkId2': 'glossary-Consolidated Provisions in Force-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "report bill : if a bill has been amended during committee debate it is reprinted in a version which highlights the changes and has the heading'for report '. this version is referred to as a report bill or an amended bill. the bill can then be presented for third reading.", 'chunkSeqId': 0, 'chunkId': 'glossary-Report Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Report Bill', 'glossaryTerm2': 'Bill Stages', 'chunkId2': 'glossary-Bill Stages-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "report bill : if a bill has been amended during committee debate it is reprinted in a version which highlights the changes and has the heading'for report '. this version is referred to as a report bill or an amended bill. the bill can then be presented for third reading.", 'chunkSeqId': 0, 'chunkId': 'glossary-Report Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Report Bill', 'glossaryTerm2': 'First Reading Bill', 'chunkId2': 'glossary-First Reading Bill-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "report bill : if a bill has been amended during committee debate it is reprinted in a version which highlights the changes and has the heading'for report '. this version is referred to as a report bill or an amended bill. the bill can then be presented for third reading.", 'chunkSeqId': 0, 'chunkId': 'glossary-Report Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Report Bill', 'glossaryTerm2': 'Third Reading Bill', 'chunkId2': 'glossary-Third Reading Bill-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': "revision : periodically ( every 10 to 20 years in b. c. ) the public statutes are revised, primarily to consolidate amendments, simplify the numbering, reorganize the content and update the language. the most recent revision was published in 1996 and is referred to as the revised statutes of british columbia, 1996 ( r. s. b. c. 1996 ). the 1996 revision contains all public acts that were in force on december 31, 1996, as they appeared on that day. the official print version of the 1996 statute revision is available from crown publications, king's printer. the 1996 revision is also available on bc laws.", 'chunkSeqId': 0, 'chunkId': 'glossary-Revision-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Revision', 'glossaryTerm2': 'R.S.B.C.', 'chunkId2': 'glossary-R.S.B.C.-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'royal assent : after a bill has passed third reading in the legislative assembly, the lieutenant governor, on behalf of the queen, assents to the bill by signing it. the bill is thereby enacted and becomes an act, i. e. a law. unless an act contains a stated effective date, or a provision requiring that it be brought into force by regulation, it comes into force on the day royal assent is given.', 'chunkSeqId': 0, 'chunkId': 'glossary-Royal Assent-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Royal Assent', 'glossaryTerm2': 'Commencement Section', 'chunkId2': 'glossary-Commencement Section-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'r. s. b. c. : the abbreviation for the revised statutes of british columbia. the citation r. s. b. c. 1996, c. 22 indicates the statute was revised and republished as chapter 22 of the 1996 revision. the revised statutes of 1996 stated the law as of december 31, 1996.', 'chunkSeqId': 0, 'chunkId': 'glossary-R.S.B.C.-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'R.S.B.C.', 'glossaryTerm2': 'Revision', 'chunkId2': 'glossary-Revision-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'second reading : at second reading members of the legislative assembly debate a bill ’ s general principles and goals. if the bill passes second reading it moves to the committee stage where it is debated provision by provision.', 'chunkSeqId': 0, 'chunkId': 'glossary-Second Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Second Reading', 'glossaryTerm2': 'Bill Stages', 'chunkId2': 'glossary-Bill Stages-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'second reading : at second reading members of the legislative assembly debate a bill ’ s general principles and goals. if the bill passes second reading it moves to the committee stage where it is debated provision by provision.', 'chunkSeqId': 0, 'chunkId': 'glossary-Second Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Second Reading', 'glossaryTerm2': 'Committee', 'chunkId2': 'glossary-Committee-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'second reading : at second reading members of the legislative assembly debate a bill ’ s general principles and goals. if the bill passes second reading it moves to the committee stage where it is debated provision by provision.', 'chunkSeqId': 0, 'chunkId': 'glossary-Second Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Second Reading', 'glossaryTerm2': 'First Reading', 'chunkId2': 'glossary-First Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'second reading : at second reading members of the legislative assembly debate a bill ’ s general principles and goals. if the bill passes second reading it moves to the committee stage where it is debated provision by provision.', 'chunkSeqId': 0, 'chunkId': 'glossary-Second Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Second Reading', 'glossaryTerm2': 'Third Reading', 'chunkId2': 'glossary-Third Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'session : a session is made up of a series of sittings of the legislative assembly during a parliament. a session begins with the speech from the throne and ends with prorogation or dissolution. at least one session of the legislative assembly is held each year.', 'chunkSeqId': 0, 'chunkId': 'glossary-Session-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Session', 'glossaryTerm2': 'Parliament', 'chunkId2': 'glossary-Parliament-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'session : a session is made up of a series of sittings of the legislative assembly during a parliament. a session begins with the speech from the throne and ends with prorogation or dissolution. at least one session of the legislative assembly is held each year.', 'chunkSeqId': 0, 'chunkId': 'glossary-Session-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Session', 'glossaryTerm2': 'Sitting', 'chunkId2': 'glossary-Sitting-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'sitting : a meeting of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Sitting-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Sitting', 'glossaryTerm2': 'Parliament', 'chunkId2': 'glossary-Parliament-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'sitting : a meeting of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Sitting-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Sitting', 'glossaryTerm2': 'Session', 'chunkId2': 'glossary-Session-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'statute : also called an act.', 'chunkSeqId': 0, 'chunkId': 'glossary-Statute-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Statute', 'glossaryTerm2': 'Act', 'chunkId2': 'glossary-Act-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'third reading : third reading is the final opportunity for the legislative assembly to debate a bill before a final vote is taken on whether to pass it, although the bill is not usually debated at this stage. once a bill has passed third reading the speaker announces that it is an act of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Third Reading', 'glossaryTerm2': 'Bill Stages', 'chunkId2': 'glossary-Bill Stages-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'third reading : third reading is the final opportunity for the legislative assembly to debate a bill before a final vote is taken on whether to pass it, although the bill is not usually debated at this stage. once a bill has passed third reading the speaker announces that it is an act of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Third Reading', 'glossaryTerm2': 'Committee', 'chunkId2': 'glossary-Committee-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'third reading : third reading is the final opportunity for the legislative assembly to debate a bill before a final vote is taken on whether to pass it, although the bill is not usually debated at this stage. once a bill has passed third reading the speaker announces that it is an act of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Third Reading', 'glossaryTerm2': 'First Reading', 'chunkId2': 'glossary-First Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'third reading : third reading is the final opportunity for the legislative assembly to debate a bill before a final vote is taken on whether to pass it, although the bill is not usually debated at this stage. once a bill has passed third reading the speaker announces that it is an act of the legislative assembly.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Third Reading', 'glossaryTerm2': 'Second Reading', 'chunkId2': 'glossary-Second Reading-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'third reading bill : a bill that has been voted on and passed by the legislative assembly with or without amendment. once the bill has passed third reading it is certified correct by the law clerk before being printed.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Third Reading Bill', 'glossaryTerm2': 'Bill Stages', 'chunkId2': 'glossary-Bill Stages-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'third reading bill : a bill that has been voted on and passed by the legislative assembly with or without amendment. once the bill has passed third reading it is certified correct by the law clerk before being printed.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Third Reading Bill', 'glossaryTerm2': 'First Reading Bill', 'chunkId2': 'glossary-First Reading Bill-seq-0'}
# [{'count(newRelationship)': 0}]
#
#
#
# {'type': 'glossary', 'text': 'third reading bill : a bill that has been voted on and passed by the legislative assembly with or without amendment. once the bill has passed third reading it is certified correct by the law clerk before being printed.', 'chunkSeqId': 0, 'chunkId': 'glossary-Third Reading Bill-seq-0', 'url': 'https://www.bclaws.gov.bc.ca/glossary.html', 'glossaryTerm1': 'Third Reading Bill', 'glossaryTerm2': 'Report Bill', 'chunkId2': 'glossary-Report Bill-seq-0'}
# [{'count(newRelationship)': 0}]

# %%
get_glossary = """
MATCH (n:UpdatedChunk) WHERE n.type="glossary" RETURN n 
"""
