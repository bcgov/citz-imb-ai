# %% [markdown]
# ## Run this notebook to initialzie the trulens DB.
# Before running this notebook, make sure you have postgres installed and you hava a database called trulens created.

# %%
# !pip install trulens
# !pip install trulens-providers-bedrock

# %%
# !pip install psycopg[binary]
# !pip install psycopg2-binary

# %%
import os

# %%
TRULENS_USER = os.getenv('TRULENS_USER')
TRULENS_PASSWORD = os.getenv('TRULENS_PASSWORD')
TRULENS_DB ='trulens'
TRULENS_PORT = os.getenv('TRULENS_PORT')
TRULENS_HOST = os.getenv('TRULENS_HOST')
TRULENS_CONNECTION_STRING = f"postgresql+psycopg2://{TRULENS_USER}:{TRULENS_PASSWORD}@{TRULENS_HOST}:{TRULENS_PORT}/{TRULENS_DB}"

# %%
from trulens.apps.app import instrument
from trulens.core import TruSession

# %%
TRULENS_CONNECTION_STRING
# Out:
# 'postgresql+psycopg2://postgres:root@trulens:5432/trulens'

# %%
TRULENS_USER
# Out:
# 'postgres'

# %%
from  trulens.core.database.connector import DBConnector

# %%
from trulens.core.session import TruSession
from trulens.core.database.connector.default import DefaultDBConnector
connector = DefaultDBConnector(database_url = TRULENS_CONNECTION_STRING)
session = TruSession(connector = connector)
# Out:
# 🦑 Initialized with db url postgresql+psycopg2://postgres:***@trulens:5432/trulens .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `TruSession` to prevent this.

# %% [markdown]
# ## Reset Database:session.reset_database()

# %%
session.reset_database()
# Out:
# Updating app_name and app_version in apps table: 0it [00:00, ?it/s]
# Updating app_id in records table: 0it [00:00, ?it/s]
# Updating app_json in apps table: 0it [00:00, ?it/s]

# %%
class RAG:
    @instrument
    def retrieve(self, query: str):
        return "hello" + query
    @instrument    
    def query(self, query:str):
        return self.retrieve(query)
rag = RAG()

# %%
from trulens.apps.app import TruApp

tru_rag = TruApp(
    rag,
    app_name="RAG",
    app_version="base",
)
# Out:
# instrumenting <class '__main__.RAG'> for base <class '__main__.RAG'>
# 	instrumenting retrieve
# 	instrumenting query

# %%
with tru_rag as recording:
    rag.query(
        "What wave of coffee culture is Starbucks seen to represent in the United States?"
    )

# %%
from trulens.dashboard import run_dashboard

run_dashboard(session, port=8501)
# Out:
# Starting dashboard ...
# Accordion(children=(VBox(children=(VBox(children=(Label(value='STDOUT'), Output())), VBox(children=(Label(valu…
# Dashboard started at http://localhost:8501 .
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %%
from trulens.dashboard import stop_dashboard

# %%
stop_dashboard()

# %%
records, feedback= session.get_records_and_feedback(app_ids=[])
# Out:
# Error encountered while attempting to retrieve feedback results. This issue may stem from a corrupted database.
# Error details: the resolved dtypes are not compatible with add.reduce. Resolved (dtype('<U4'), dtype('<U4'), dtype('<U8'))

# %%
records
# Out:
#                                        app_id  \
# 0   app_hash_c5cfc6186b01d789f4d164f7b25b5891
# 1   app_hash_c5cfc6186b01d789f4d164f7b25b5891
# 2   app_hash_c5cfc6186b01d789f4d164f7b25b5891
# 3   app_hash_c5cfc6186b01d789f4d164f7b25b5891
# 4   app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 5   app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 6   app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 7   app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 8   app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 9   app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 10  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 11  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 12  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 13  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 14  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 15  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 16  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 17  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# 18  app_hash_40be58a0944f2f2c08bdb7809f9c82b9
# ...
