# %% [markdown]
# #### 1. Setup and Configuration

# %%
import os
import json
from concurrent.futures import ThreadPoolExecutor
from Neo4jRetrieval import Neo4jRetrieval
from AzureQuery import AzureQuery

# Define the search question
question = "Identify all British Columbia regulations that contain clauses that specify how the regulation applies to goods or services originating outside the province"

# Neo4j Configuration
NEO4J_URI = "bolt://localhost:7687"
NEO4J_USERNAME = "admin"
NEO4J_PASSWORD = "admin"

# Azure Configuration
endpoint = os.getenv("AZURE_AI_ENDPOINT", "")
key = os.getenv("AZURE_AI_KEY", "")

azure = AzureQuery(endpoint, key)

# %% [markdown]
# #### 2a. Generate Initial Terms from User Query

# %%
def generate_initial_terms(question):
    prompt = f"""
    Based on this question about British Columbia regulations:
    "{question}"
    
    Generate 8-10 search terms focused on INTERPROVINCIAL and INTERTERRITORIAL trade barriers within Canada only (NOT international trade):
    
    BROAD terms (3-4 terms) - General concepts:
    - Examples: "interprovincial", "interterritorial", "out-of-province", "jurisdiction"
    
    SPECIFIC terms (4-6 terms) - Precise legal/regulatory phrases:  
    - Examples: "interprovincial trade barriers", "territorial application within Canada", "cross-provincial commerce"
    
    Focus on terms related to:
    - Trade barriers between Canadian provinces and territories
    - Provincial regulatory authority over out-of-province goods/services
    - Interprovincial goods and services classification
    - Territorial boundaries within Canada
    - Province-specific standards
    
    Return the terms as a Python list format only, no explanations.
    Example format: ["broad_term1", "specific_phrase_here", "broad_term2", "detailed_regulatory_concept"]
    """
    
    response = azure.call_agent(prompt)
    try:
        import ast
        terms = ast.literal_eval(response.strip())
        return terms
    except:
        # Fallback with mix of broad and specific
        return ["extraprovincial", "place of supply rules", "interprovincial", "cross-border commerce", 
                "out-of-province", "territorial application", "jurisdiction", "goods and services classification"]

# Generate new terms based on the original question and existing terms
def generate_additional_terms(question, existing_terms):
    existing_terms_str = ", ".join(existing_terms)
    
    prompt = f"""
    Based on this original question about British Columbia regulations:
    "{question}"
    
    We already have these search terms: {existing_terms_str}
    
    Generate 4-6 NEW search terms that maintain a balance of BROAD and SPECIFIC terms, focused on INTERPROVINCIAL/INTERTERRITORIAL trade within Canada only:
    
    BROAD terms (2-3 new terms) - Single words or short general concepts:
    - Examples: "territorial", "jurisdictional", "provincial"
    
    SPECIFIC terms (2-3 new terms) - Multi-word precise legal phrases:
    - Examples: "interprovincial supply chain regulations", "territorial compliance requirements", "inter-jurisdictional trade rules within Canada"
    
    Ensure these are different from existing terms and focus on:
    - Trade barriers between Canadian provinces and territories
    - Provincial regulatory authority over other provinces/territories
    - Interprovincial goods and services classification
    
    Stay grounded to the original question: "{question}"
    
    If no relevant new terms can be generated, return an empty list: []
    
    Return the terms in list format only, no explanations, no code blocks.
    Example format: ["broad_term", "specific multi-word phrase", "another_broad_term"] or []
    """
    
    response = azure.call_agent(prompt)
    print(response)
    try:
        import ast
        terms = ast.literal_eval(response.strip())
        print(terms)
        return terms if terms else []
    except:
        return []

# Generate initial terms
all_terms = set()
initial_terms = generate_initial_terms(question)
all_terms.update(initial_terms)
print("Initial terms:", initial_terms)



# Loop to generate additional terms
target_terms = 30  # Prevent infinite loops
iteration = 0

while len(all_terms) < target_terms:
    new_terms = generate_additional_terms(question, all_terms)
    if not new_terms:  # No more terms to generate
        print(f"No more new terms generated after {iteration + 1} iterations")
        break
    
    all_terms.update(new_terms)
    print(f"Iteration {iteration + 1} - New terms added:", new_terms)
    iteration += 1

print(f"Total terms generated: {len(all_terms)}")
print("All terms:", all_terms)
# Out:
# Initial terms: ['extraprovincial', 'place of supply rules', 'interprovincial', 'cross-border commerce', 'out-of-province', 'territorial application', 'jurisdiction', 'goods and services classification']
# ["interterritorial", "regional", "interprovincial trade barriers", "provincial cross-border regulations", "intra-Canadian trade compliance"]
# ['interterritorial', 'regional', 'interprovincial trade barriers', 'provincial cross-border regulations', 'intra-Canadian trade compliance']
# Iteration 1 - New terms added: ['interterritorial', 'regional', 'interprovincial trade barriers', 'provincial cross-border regulations', 'intra-Canadian trade compliance']
# ["territoriality", "jurisdictional application", "interjurisdictional commerce frameworks", "interprovincial regulatory compliance", "provincial trade enforcement policies"]
# ['territoriality', 'jurisdictional application', 'interjurisdictional commerce frameworks', 'interprovincial regulatory compliance', 'provincial trade enforcement policies']
# Iteration 2 - New terms added: ['territoriality', 'jurisdictional application', 'interjurisdictional commerce frameworks', 'interprovincial regulatory compliance', 'provincial trade enforcement policies']
# ["interprovincial", "jurisdiction", "cross-border trade", "interprovincial commerce conditions", "extraprovincial regulatory frameworks", "cross-province trade specifications"]
# ['interprovincial', 'jurisdiction', 'cross-border trade', 'interprovincial commerce conditions', 'extraprovincial regulatory frameworks', 'cross-province trade specifications']
# Iteration 3 - New terms added: ['interprovincial', 'jurisdiction', 'cross-border trade', 'interprovincial commerce conditions', 'extraprovincial regulatory frameworks', 'cross-province trade specifications']
# ["territorial trade", "provincial trade governance", "region-specific trade regulations", "cross-territorial supply chain rules", "provincial goods classification standards"]
# ['territorial trade', 'provincial trade governance', 'region-specific trade regulations', 'cross-territorial supply chain rules', 'provincial goods classification standards']
# Iteration 4 - New terms added: ['territorial trade', 'provincial trade governance', 'region-specific trade regulations', 'cross-territorial supply chain rules', 'provincial goods classification standards']
# ["regional trade barriers", "interterritorial commerce guidelines", "jurisdictional trade governance", "interprovincial regulatory distinctions", "territorial market entry conditions"]
# ['regional trade barriers', 'interterritorial commerce guidelines', 'jurisdictional trade governance', 'interprovincial regulatory distinctions', 'territorial market entry conditions']
# Iteration 5 - New terms added: ['regional trade barriers', 'interterritorial commerce guidelines', 'jurisdictional trade governance', 'interprovincial regulatory distinctions', 'territorial market entry conditions']
# Total terms generated: 32
# All terms: {'cross-territorial supply chain rules', 'jurisdiction', 'regional trade barriers', 'territorial trade', 'jurisdictional trade governance', 'goods and services classification', 'provincial cross-border regulations', 'cross-border commerce', 'cross-province trade specifications', 'regional', 'region-specific trade regulations', 'extraprovincial', 'jurisdictional application', 'territorial application', 'interterritorial', 'territorial market entry conditions', 'cross-border trade', 'interjurisdictional commerce frameworks', 'interprovincial regulatory compliance', 'interprovincial commerce conditions', 'intra-Canadian trade compliance', 'provincial trade governance', 'territoriality', 'interterritorial commerce guidelines', 'extraprovincial regulatory frameworks', 'interprovincial trade barriers', 'provincial trade enforcement policies', 'place of supply rules', 'provincial goods classification standards', 'interprovincial regulatory distinctions', 'interprovincial', 'out-of-province'}

# %% [markdown]
# #### 2b. Add Seed Terms to Set
# These are terms that have been manually identified as flags for potentially relevant chunks of information.

# %%
# Load terms from file
with open('seed_words.txt', 'r') as f:
    seed_terms = [line.strip() for line in f if line.strip()]
    # Combine all terms
    all_terms.update(seed_terms)
    print(all_terms)
# Out:
# {'trade barrier', 'cross-territorial supply chain rules', 'profession', 'jurisdiction', 'regional trade barriers', 'territorial trade', 'jurisdictional trade governance', 'goods and services classification', 'procurement', 'provincial cross-border regulations', 'cross-border commerce', 'cross-province trade specifications', 'regional', 'region-specific trade regulations', 'extraprovincial', 'jurisdictional application', 'certification', 'authorization', 'territorial application', 'interterritorial', 'territorial market entry conditions', 'authority', 'cross-border trade', 'interjurisdictional commerce frameworks', 'licence', 'permit', 'interprovincial regulatory compliance', 'interprovincial commerce conditions', 'good', 'intra-Canadian trade compliance', 'provincial trade governance', 'territoriality', 'interterritorial commerce guidelines', 'extraprovincial regulatory frameworks', 'service', 'toll', 'fee', 'interprovincial trade barriers', 'charge', 'specification', 'provincial trade enforcement policies', 'approval', 'place of supply rules', 'provincial goods classification standards', 'interprovincial regulatory distinctions', 'occupation', 'interprovincial', 'out-of-province'}

# %% [markdown]
# #### 3. Refine and Expand Terms

# %%
def refine_terms(all_terms):
    refined_terms = []
    blacklisted_terms = []
    
    # First, generate blacklisted terms
    blacklist_prompt = f"""
    Based on this original question about British Columbia regulations:
    "{question}"
    
    Generate a list of blacklisted terms that would give FALSE POSITIVES for interprovincial/interterritorial trade within Canada.
    
    Focus on terms that relate to:
    - International trade (outside Canada)
    - Foreign countries or jurisdictions
    - Global commerce
    - Import/export with non-Canadian entities
    - Terms that might confuse interprovincial with international
    
    Stay grounded to the original question: "{question}"
    Keep in mind we want out-of-province but NOT out-of-country content.
    
    Return 5-8 blacklisted terms in list format only, no explanations, no code blocks.
    Example format: ["international", "foreign trade", "import duties", "export regulations"]
    """
    
    blacklist_response = azure.call_agent(blacklist_prompt)
    try:
        import ast
        blacklisted_terms = ast.literal_eval(blacklist_response.strip())
        blacklisted_terms = [term.lower() for term in blacklisted_terms]
    except:
        blacklisted_terms = ["international", "foreign", "import", "export", "overseas", "global trade"]
    
    print(f"Blacklisted terms: {blacklisted_terms}")
    
    # Then refine existing terms
    for term in all_terms:
        is_broad = len(term.split()) <= 2 and not any(keyword in term.lower() 
                     for keyword in ['rule', 'regulation', 'requirement', 'compliance', 'application'])
        
        expand_prompt = f"""
        Based on this original question about British Columbia regulations:
        "{question}"
        
        Expand this {"broad" if is_broad else "specific"} term: "{term}"
        
        Focus on interprovincial/interterritorial trade within Canada only (NOT international):
        - Trade barriers between Canadian provinces and territories
        - Out-of-province but within Canada regulations
        - Provincial regulatory authority over other provinces/territories
        
        Stay grounded to the original question: "{question}"
        
        Generate 2-4 related {"broad" if is_broad else "specific"} terms that enhance search coverage for:
        - Regulatory language alternatives  
        - Jurisdictional concepts within Canada
        {"- Keep terms general and short (1-2 words)" if is_broad else "- Keep terms specific and detailed (multi-word phrases)"}
        
        Return the terms in list format only, no explanations, no code blocks.
        Example format: {["broad1", "broad2", "broad3"] if is_broad else ["specific detailed phrase 1", "specific regulatory concept 2", "specific legal term 3"]}
        """
        
        response = azure.call_agent(expand_prompt)
        try:
            import ast
            expanded_terms = ast.literal_eval(response.strip())
            refined_terms.extend(expanded_terms)
        except:
            refined_terms.append(term)  # Keep original if expansion fails
    
    return refined_terms, blacklisted_terms

refined_terms_nested, blacklisted_terms = refine_terms(all_terms)
print("Refined terms (nested):", refined_terms_nested)
print("Blacklisted terms:", blacklisted_terms)

# Flatten nested list of terms to a single list
def flatten_terms(nested_terms):
    flattened = []
    for item in nested_terms:
        if isinstance(item, list):
            flattened.extend(item)
        else:
            flattened.append(item)
    return flattened

# Flatten the nested terms
flattened_terms = flatten_terms(refined_terms_nested)
print(f"Flattened terms ({len(flattened_terms)}): {flattened_terms}")

# Remove surrounding quotes from terms
def remove_quotes(terms):
    cleaned_terms = []
    for term in terms:
        # Remove surrounding quotes if they exist
        cleaned_term = term.strip('"\'')
        cleaned_terms.append(cleaned_term)
    return cleaned_terms

# Clean the terms
cleaned_terms = remove_quotes(flattened_terms)
print(f"Cleaned terms ({len(cleaned_terms)}): {cleaned_terms}")

# Convert all terms to lowercase and remove duplicates
def lowercase_terms(terms):
    lowercase_terms = list(set([term.lower() for term in terms]))
    return lowercase_terms

lowercased_terms = lowercase_terms(cleaned_terms)
print(f"Lowercased unique terms ({len(lowercased_terms)}): {lowercased_terms}")

# Filter out blacklisted terms
def filter_blacklisted_terms(terms, blacklisted_terms):
    filtered_terms = [term for term in terms if term not in blacklisted_terms]
    return filtered_terms

final_terms = filter_blacklisted_terms(lowercased_terms, blacklisted_terms)
print(f"Final filtered terms ({len(final_terms)}): {final_terms}")
# Out:
# Blacklisted terms: ['international', 'global markets', 'foreign jurisdictions', 'non-canadian entities', 'import/export tariffs', 'overseas commerce', 'worldwide trade']
# Refined terms (nested): ['interprovincial trade', 'territorial regulation', 'cross-border commerce', 'regional jurisdiction', 'interprovincial trade compliance standards', 'domestic territorial trade provisions', 'regional supply chain governance', 'out-of-province regulatory enforcement', 'occupation', 'trade restrictions', 'external jurisdiction', 'out-of-province provisions', 'interprovincial', 'trade barriers', 'cross-border', 'regulatory scope', 'interprovincial trade restrictions', 'cross-border regulatory compliance', 'provincial jurisdictional authority', 'inter-territorial trade regulations', 'interprovincial trade', 'cross-border commerce', 'jurisdictional authority', 'regional regulation', 'interprovincial commerce clauses', 'cross-border regulatory schema', 'internal Canadian trade provisions', 'provincial regulatory harmonization', 'interprovincial trade regulations', 'out-of-province trade compliance', 'Canadian interjurisdictional trade laws', 'provincial jurisdiction over external entities', 'interprovincial trade', 'territorial regulations', 'territorial compliance', 'Canadian jurisdiction', 'interprovincial trade restrictions', 'interterritorial regulatory agreements', 'Canadian provincial jurisdiction protocols', 'cross-provincial goods and services regulations', 'interprovincial trade', 'trade restrictions', 'regulatory jurisdiction', 'provincial authority', 'interprovincial trade restrictions', 'territorial jurisdiction over external goods', 'provincial interjurisdictional regulations', 'Canadian internal trade compliance clauses', 'interjurisdictional', 'trade barriers', 'cross-border', 'interprovincial', 'interprovincial commerce regulation', 'cross-jurisdictional trade clauses', 'out-of-province goods governance', 'interterritorial trade provisions', 'interjurisdictional', 'cross-provincial', 'domestic trade', 'regional regulations', 'interprovincial trade regulation', 'interterritorial commerce clause', 'extrajurisdictional application within Canada', 'provincial regulatory jurisdiction over external goods/services', 'accreditation', 'approval', 'jurisdiction', 'trade barriers', 'permit', 'jurisdiction', 'compliance', 'interjurisdictional', 'interprovincial trade provisions', 'cross-border regulatory frameworks', 'interjurisdictional compliance clauses', 'cross-provincial legal authority', 'interprovincial', 'cross-jurisdictional', 'intra-Canadian', 'interregional', 'interprovincial trade regulations', 'Canadian jurisdictional enforcement', 'cross-border provincial trade restrictions', 'interterritorial commerce stipulations', 'jurisdiction', 'interprovincial', 'regulatory scope', 'trade limitation', 'interprovincial trade', 'interterritorial commerce', 'domestic trade barriers', 'jurisdictional authority', 'interprovincial trade regulations', 'cross-provincial commerce clauses', 'interterritorial trade barriers', 'out-of-province regulatory impact', 'permit', 'authorization', 'interprovincial trade', 'extra-provincial regulations', 'authorization', 'jurisdiction', 'compliance', 'interjurisdictional', 'interprovincial trade barriers Canada', 'Canadian provincial regulatory harmonization', 'non-resident goods regulation Canada', 'provincial trade agreements Canada', 'provincial trade barriers', 'out-of-province regulatory framework', 'jurisdictional control over interprovincial trade', 'provincial oversight of interterritorial commerce', 'commodities', 'interprovincial trade', 'jurisdictional authority', 'external services', 'interprovincial trade regulations', 'out-of-province regulatory compliance', 'cross-border provincial laws', 'interjurisdictional trade restrictions', 'interprovincial trade regulations', 'jurisdictional trade barriers within Canada', 'cross-provincial regulatory compliance', 'territorial commerce governance clauses', 'interprovincial commerce', 'trade restrictions', 'cross-jurisdictional', 'extra-provincial', 'interprovincial trade regulation', 'domestic trade barriers within Cana ...
# Blacklisted terms: ['international', 'global markets', 'foreign jurisdictions', 'non-canadian entities', 'import/export tariffs', 'overseas commerce', 'worldwide trade']
# Flattened terms (192): ['interprovincial trade', 'territorial regulation', 'cross-border commerce', 'regional jurisdiction', 'interprovincial trade compliance standards', 'domestic territorial trade provisions', 'regional supply chain governance', 'out-of-province regulatory enforcement', 'occupation', 'trade restrictions', 'external jurisdiction', 'out-of-province provisions', 'interprovincial', 'trade barriers', 'cross-border', 'regulatory scope', 'interprovincial trade restrictions', 'cross-border regulatory compliance', 'provincial jurisdictional authority', 'inter-territorial trade regulations', 'interprovincial trade', 'cross-border commerce', 'jurisdictional authority', 'regional regulation', 'interprovincial commerce clauses', 'cross-border regulatory schema', 'internal Canadian trade provisions', 'provincial regulatory harmonization', 'interprovincial trade regulations', 'out-of-province trade compliance', 'Canadian interjurisdictional trade laws', 'provincial jurisdiction over external entities', 'interprovincial trade', 'territorial regulations', 'territorial compliance', 'Canadian jurisdiction', 'interprovincial trade restrictions', 'interterritorial regulatory agreements', 'Canadian provincial jurisdiction protocols', 'cross-provincial goods and services regulations', 'interprovincial trade', 'trade restrictions', 'regulatory jurisdiction', 'provincial authority', 'interprovincial trade restrictions', 'territorial jurisdiction over external goods', 'provincial interjurisdictional regulations', 'Canadian internal trade compliance clauses', 'interjurisdictional', 'trade barriers', 'cross-border', 'interprovincial', 'interprovincial commerce regulation', 'cross-jurisdictional trade clauses', 'out-of-province goods governance', 'interterritorial trade provisions', 'interjurisdictional', 'cross-provincial', 'domestic trade', 'regional regulations', 'interprovincial trade regulation', 'interterritorial commerce clause', 'extrajurisdictional application within Canada', 'provincial regulatory jurisdiction over external goods/services', 'accreditation', 'approval', 'jurisdiction', 'trade barriers', 'permit', 'jurisdiction', 'compliance', 'interjurisdictional', 'interprovincial trade provisions', 'cross-border regulatory frameworks', 'interjurisdictional compliance clauses', 'cross-provincial legal authority', 'interprovincial', 'cross-jurisdictional', 'intra-Canadian', 'interregional', 'interprovincial trade regulations', 'Canadian jurisdictional enforcement', 'cross-border provincial trade restrictions', 'interterritorial commerce stipulations', 'jurisdiction', 'interprovincial', 'regulatory scope', 'trade limitation', 'interprovincial trade', 'interterritorial commerce', 'domestic trade barriers', 'jurisdictional authority', 'interprovincial trade regulations', 'cross-provincial commerce clauses', 'interterritorial trade barriers', 'out-of-province regulatory impact', 'permit', 'authorization', 'interprovincial trade', 'extra-provincial regulations', 'authorization', 'jurisdiction', 'compliance', 'interjurisdictional', 'interprovincial trade barriers Canada', 'Canadian provincial regulatory harmonization', 'non-resident goods regulation Canada', 'provincial trade agreements Canada', 'provincial trade barriers', 'out-of-province regulatory framework', 'jurisdictional control over interprovincial trade', 'provincial oversight of interterritorial commerce', 'commodities', 'interprovincial trade', 'jurisdictional authority', 'external services', 'interprovincial trade regulations', 'out-of-province regulatory compliance', 'cross-border provincial laws', 'interjurisdictional trade restrictions', 'interprovincial trade regulations', 'jurisdictional trade barriers within Canada', 'cross-provincial regulatory compliance', 'territorial commerce governance clauses', 'interprovincial commerce', 'trade restrictions', 'cross-jurisdictional', 'extra-provincial', 'interprovincial trade regulation', 'domestic trade barriers within Canad ...
# Cleaned terms (192): ['interprovincial trade', 'territorial regulation', 'cross-border commerce', 'regional jurisdiction', 'interprovincial trade compliance standards', 'domestic territorial trade provisions', 'regional supply chain governance', 'out-of-province regulatory enforcement', 'occupation', 'trade restrictions', 'external jurisdiction', 'out-of-province provisions', 'interprovincial', 'trade barriers', 'cross-border', 'regulatory scope', 'interprovincial trade restrictions', 'cross-border regulatory compliance', 'provincial jurisdictional authority', 'inter-territorial trade regulations', 'interprovincial trade', 'cross-border commerce', 'jurisdictional authority', 'regional regulation', 'interprovincial commerce clauses', 'cross-border regulatory schema', 'internal Canadian trade provisions', 'provincial regulatory harmonization', 'interprovincial trade regulations', 'out-of-province trade compliance', 'Canadian interjurisdictional trade laws', 'provincial jurisdiction over external entities', 'interprovincial trade', 'territorial regulations', 'territorial compliance', 'Canadian jurisdiction', 'interprovincial trade restrictions', 'interterritorial regulatory agreements', 'Canadian provincial jurisdiction protocols', 'cross-provincial goods and services regulations', 'interprovincial trade', 'trade restrictions', 'regulatory jurisdiction', 'provincial authority', 'interprovincial trade restrictions', 'territorial jurisdiction over external goods', 'provincial interjurisdictional regulations', 'Canadian internal trade compliance clauses', 'interjurisdictional', 'trade barriers', 'cross-border', 'interprovincial', 'interprovincial commerce regulation', 'cross-jurisdictional trade clauses', 'out-of-province goods governance', 'interterritorial trade provisions', 'interjurisdictional', 'cross-provincial', 'domestic trade', 'regional regulations', 'interprovincial trade regulation', 'interterritorial commerce clause', 'extrajurisdictional application within Canada', 'provincial regulatory jurisdiction over external goods/services', 'accreditation', 'approval', 'jurisdiction', 'trade barriers', 'permit', 'jurisdiction', 'compliance', 'interjurisdictional', 'interprovincial trade provisions', 'cross-border regulatory frameworks', 'interjurisdictional compliance clauses', 'cross-provincial legal authority', 'interprovincial', 'cross-jurisdictional', 'intra-Canadian', 'interregional', 'interprovincial trade regulations', 'Canadian jurisdictional enforcement', 'cross-border provincial trade restrictions', 'interterritorial commerce stipulations', 'jurisdiction', 'interprovincial', 'regulatory scope', 'trade limitation', 'interprovincial trade', 'interterritorial commerce', 'domestic trade barriers', 'jurisdictional authority', 'interprovincial trade regulations', 'cross-provincial commerce clauses', 'interterritorial trade barriers', 'out-of-province regulatory impact', 'permit', 'authorization', 'interprovincial trade', 'extra-provincial regulations', 'authorization', 'jurisdiction', 'compliance', 'interjurisdictional', 'interprovincial trade barriers Canada', 'Canadian provincial regulatory harmonization', 'non-resident goods regulation Canada', 'provincial trade agreements Canada', 'provincial trade barriers', 'out-of-province regulatory framework', 'jurisdictional control over interprovincial trade', 'provincial oversight of interterritorial commerce', 'commodities', 'interprovincial trade', 'jurisdictional authority', 'external services', 'interprovincial trade regulations', 'out-of-province regulatory compliance', 'cross-border provincial laws', 'interjurisdictional trade restrictions', 'interprovincial trade regulations', 'jurisdictional trade barriers within Canada', 'cross-provincial regulatory compliance', 'territorial commerce governance clauses', 'interprovincial commerce', 'trade restrictions', 'cross-jurisdictional', 'extra-provincial', 'interprovincial trade regulation', 'domestic trade barriers within Canada' ...
# Lowercased unique terms (132): ['territorial commerce governance clauses', 'regional regulation', 'territorial', 'canadian jurisdictional enforcement', 'cross-provincial legal authority', 'jurisdictional oversight within canada', 'interterritorial commerce stipulations', 'non-resident goods regulation canada', 'interjurisdictional', 'domestic trade barriers within canada', 'cross-border provincial laws', 'commodities', 'interprovincial trade restrictions', 'cross-border trade governance', 'provincial oversight', 'interprovincial commerce', 'provincial regulatory harmonization', 'provincial regulatory jurisdiction over external goods/services', 'external jurisdiction', 'cross-border trade compliance', 'canadian interjurisdictional trade laws', 'interjurisdictional trade restrictions', 'intra-canadian commerce policy', 'permission', 'cross-provincial regulatory compliance', 'canadian jurisdiction', 'interprovincial', 'external goods', 'out-of-province trade compliance', 'territorial compliance', 'out-of-province regulatory enforcement', 'approval', 'interprovincial trade regulation', 'cross-border regulatory schema', 'intra-canadian', 'interterritorial commerce regulations', 'jurisdictional regulatory frameworks in canada', 'extra-provincial regulations', 'provincial oversight of interterritorial commerce', 'out-of-province provisions', 'interprovincial trade compliance standards', 'domestic trade barriers', 'interprovincial trade provisions', 'regional jurisdiction', 'cross-border commerce', 'trade barriers', 'trade restrictions', 'extra-provincial commerce regulations', 'regulatory harmonization between provinces', 'cross-provincial goods and services regulations', 'interprovincial commerce regulation', 'authorization', 'jurisdictional control over interprovincial trade', 'tariff', 'cross-border regulations', 'provincial scope', 'cross-border', 'interterritorial trade barriers', 'external services', 'extraterritorial', 'cross-border regulatory compliance', 'provincial jurisdictional authority', 'interprovincial commerce clauses', 'extraprovincial trade compliance', 'inter-provincial commerce restrictions', 'interterritorial commerce clause', 'external origin', 'regulatory jurisdiction', 'canadian internal trade compliance clauses', 'cross-border provincial controls', 'interjurisdictional trade compliance', 'out-of-province goods governance', 'extra-provincial', 'regional trade legislation impact', 'out-of-province regulatory framework', 'cross-provincial', 'interregional', 'domestic trade', 'interterritorial commerce', 'jurisdictional trade barriers within canada', 'accreditation', 'cross-provincial regulatory provisions', 'out-of-province regulatory impact', 'oversight', 'canadian provincial regulatory harmonization', 'provincial interjurisdictional regulations', 'permit', 'provincial trade barriers', 'territorial regulations', 'inter-territorial trade regulations', 'provincial trade agreements canada', 'interprovincial trade barriers', 'extra-provincial regulations enforcement', 'occupation', 'territorial regulation', 'cross-jurisdictional trade clauses', 'out-of-province regulatory provisions', 'cross-border provincial trade restrictions', 'trade', 'provincial jurisdiction over external entities', 'jurisdiction', 'jurisdictional', 'extrajurisdictional authority', 'cross-border goods and services regulation', 'jurisdictional authority', 'provincial authority', 'interprovincial trade regulations', 'interjurisdictional compliance clauses', 'provincial jurisdiction over interprovincial goods', 'cross-jurisdictional', 'interterritorial trade provisions', 'canadian provincial jurisdiction protocols', 'regulatory scope', 'professional', 'cross-border regulatory frameworks', 'levy', 'interprovincial supply chain regulations', 'territorial jurisdiction over external goods', 'compliance', 'cross-provincial commerce clauses', 'regional regulations', 'charge', 'extrajurisdictional application within canada', 'cross-border trade within  ...
# Final filtered terms (132): ['territorial commerce governance clauses', 'regional regulation', 'territorial', 'canadian jurisdictional enforcement', 'cross-provincial legal authority', 'jurisdictional oversight within canada', 'interterritorial commerce stipulations', 'non-resident goods regulation canada', 'interjurisdictional', 'domestic trade barriers within canada', 'cross-border provincial laws', 'commodities', 'interprovincial trade restrictions', 'cross-border trade governance', 'provincial oversight', 'interprovincial commerce', 'provincial regulatory harmonization', 'provincial regulatory jurisdiction over external goods/services', 'external jurisdiction', 'cross-border trade compliance', 'canadian interjurisdictional trade laws', 'interjurisdictional trade restrictions', 'intra-canadian commerce policy', 'permission', 'cross-provincial regulatory compliance', 'canadian jurisdiction', 'interprovincial', 'external goods', 'out-of-province trade compliance', 'territorial compliance', 'out-of-province regulatory enforcement', 'approval', 'interprovincial trade regulation', 'cross-border regulatory schema', 'intra-canadian', 'interterritorial commerce regulations', 'jurisdictional regulatory frameworks in canada', 'extra-provincial regulations', 'provincial oversight of interterritorial commerce', 'out-of-province provisions', 'interprovincial trade compliance standards', 'domestic trade barriers', 'interprovincial trade provisions', 'regional jurisdiction', 'cross-border commerce', 'trade barriers', 'trade restrictions', 'extra-provincial commerce regulations', 'regulatory harmonization between provinces', 'cross-provincial goods and services regulations', 'interprovincial commerce regulation', 'authorization', 'jurisdictional control over interprovincial trade', 'tariff', 'cross-border regulations', 'provincial scope', 'cross-border', 'interterritorial trade barriers', 'external services', 'extraterritorial', 'cross-border regulatory compliance', 'provincial jurisdictional authority', 'interprovincial commerce clauses', 'extraprovincial trade compliance', 'inter-provincial commerce restrictions', 'interterritorial commerce clause', 'external origin', 'regulatory jurisdiction', 'canadian internal trade compliance clauses', 'cross-border provincial controls', 'interjurisdictional trade compliance', 'out-of-province goods governance', 'extra-provincial', 'regional trade legislation impact', 'out-of-province regulatory framework', 'cross-provincial', 'interregional', 'domestic trade', 'interterritorial commerce', 'jurisdictional trade barriers within canada', 'accreditation', 'cross-provincial regulatory provisions', 'out-of-province regulatory impact', 'oversight', 'canadian provincial regulatory harmonization', 'provincial interjurisdictional regulations', 'permit', 'provincial trade barriers', 'territorial regulations', 'inter-territorial trade regulations', 'provincial trade agreements canada', 'interprovincial trade barriers', 'extra-provincial regulations enforcement', 'occupation', 'territorial regulation', 'cross-jurisdictional trade clauses', 'out-of-province regulatory provisions', 'cross-border provincial trade restrictions', 'trade', 'provincial jurisdiction over external entities', 'jurisdiction', 'jurisdictional', 'extrajurisdictional authority', 'cross-border goods and services regulation', 'jurisdictional authority', 'provincial authority', 'interprovincial trade regulations', 'interjurisdictional compliance clauses', 'provincial jurisdiction over interprovincial goods', 'cross-jurisdictional', 'interterritorial trade provisions', 'canadian provincial jurisdiction protocols', 'regulatory scope', 'professional', 'cross-border regulatory frameworks', 'levy', 'interprovincial supply chain regulations', 'territorial jurisdiction over external goods', 'compliance', 'cross-provincial commerce clauses', 'regional regulations', 'charge', 'extrajurisdictional application within canada', 'cross-border trade within can ...

# %% [markdown]
# #### 4. Search Neo4j Database for Matching Nodes

# %%
# Use the generated terms for searching
terms = final_terms

neo4j_worker = Neo4jRetrieval(NEO4J_URI, NEO4J_USERNAME, NEO4J_PASSWORD)
nodes = neo4j_worker.search_many(terms, label='latest')
print(f"{len(nodes)} nodes found using generated terms")
neo4j_worker.close()
# Out:
# 17324 nodes found using generated terms

# %% [markdown]
# #### 5. Define Relevance Assessment Function

# %%
def create_prompt(question, node):
    prompt = f"""
    Your task is to determine if the following object is related to the question: "{question}".

    Object: {node}

    Focus on content that addresses:
    - Trade barriers between Canadian provinces and territories
    - Out-of-province (but within Canada) goods and services
    - Interprovincial regulatory compliance
    - NOT international or out-of-country trade

    Stay grounded to the original question about interprovincial/interterritorial regulations within Canada.

    If the object is related to interprovincial/interterritorial trade within Canada, return "1". 
    If it is not related or deals with international trade, return "0".
    Do not return any explanation, just the number.

    For example:
    Question: "What BC regulations have clauses about extraprovincial services?"
    Object: {{ "text": "This regulation applies to services provided from Alberta to British Columbia customers." }}
    Response: 1
    """
    return prompt

# %% [markdown]
# #### 6. Filter Nodes for Relevance Using LLM

# %%
related_set = set()
unrelated_set = set()

# Load existing related and unrelated nodes from files
if os.path.exists('related_nodes_V4.jsonl'):
    with open('related_nodes_V4.jsonl', 'r') as f:
        for line in f:
            node = json.loads(line.strip())
            related_set.update(node.get("elementId"))
if os.path.exists('unrelated_nodes.txt'):
    with open('unrelated_nodes.txt', 'r') as f:
        for line in f:
            element_id = line.strip()
            unrelated_set.update(element_id)

new_related_nodes = []
with open("related_nodes_V4.jsonl", "a") as rf:
  with open("unrelated_nodes.txt", "a") as uf:

    # Use LLM to determine if the node is relevant
    def add_or_dispose(node):
        element_id = node.get("elementId")
        # If this node is already in related or unrelated nodes, skip it
        if element_id in related_set or element_id in unrelated_set:
            return
        try:
            prompt = create_prompt(question, node)
            azure_response = azure.call_agent(prompt)
            print(azure_response.strip())
            if int(azure_response.strip()):
                new_related_nodes.append(node)
                related_set.update(node.get("elementId"))
                rf.write(json.dumps(node) + "\n")
                print("Relevant:", node.get("text")[:100] + "...")
            else:
                unrelated_set.update(node.get("elementId"))
                uf.write((node.get("elementId")) + "\n")
                print("Not relevant:", node.get("text")[:50] + "...")
        except Exception as e:
            print("Error processing azure_response:", azure_response, e)
            pass

    # Process nodes in parallel
    with ThreadPoolExecutor(10) as executor:
        executor.map(add_or_dispose, nodes)
    
print(f"{len(new_related_nodes)} relevant nodes found")
# Out:
# 0
# Not relevant: the area of the greater vancouver water district s...
# 0
# Not relevant: 1 the corporation shall extend its service to and ...
# 0
# Not relevant: 1 in this part ,  court means a court of british c...
# 0
# Not relevant: a court has territorial competence in a proceeding...
# 0
# Not relevant: country other than canada ,  including ,  in addit...
# 0
# Not relevant: a court that under section 3 lacks territorial com...
# 0
# Not relevant: a court has territorial competence in a proceeding...
# 0
# Not relevant: in this act :  person includes a state ;  plaintif...
# 0
# Not relevant: 1 if an affidavit in respect of the lien has been ...
# 0
# Not relevant: a court has territorial competence in a proceeding...
# 0
# Not relevant: 1 after considering the interests of the parties t...
# 0
# Not relevant: 1 on a transfer of a proceeding from the supreme c...
# 0
# Not relevant: 1 after the filing of a request made by a court ou...
# 0
# Not relevant: 1 the supreme court by order may request a court o...
# 0
# Not relevant: if there is a conflict or inconsistency between th...
# 0
# Not relevant: 1 after the transfer of a proceeding to the suprem...
# 0
# Not relevant: 1 in a proceeding transferred to the supreme court...
# 0
# Not relevant: in this act :  clerk of the peace includes the pro...
# 0
# Not relevant: 0 . 1 in this section ,  improvements ,  land and ...
# 0
# Not relevant: eticket means a violation ticket described in sect...
# 0
# Not relevant: subject to section 2 . 1 of the provincial court a...
# 0
# Not relevant: all the land the fee of which is in the crown in r...
# 0
# Not relevant: 1 for this act ,  if an offence is committed in or...
# 0
# Not relevant: 1 on a transfer of a proceeding to the supreme cou...
# 0
# Not relevant: ;  prosecutor means an informant or the attorney g...
# 0
# Not relevant: 1 a justice who is satisfied by information on oat...
# 0
# Not relevant: been endorsed in form 16 by a justice who has juri...
# 0
# Not relevant: 1 if a peace officer believes that an offence puni...
# 0
# Not relevant: 1 if a trial is commenced before a justice and tha...
# 0
# Not relevant: issued by telephone or other means of telecommunic...
# 0
# Not relevant: issue a warrant to a peace officer that e confers ...
# 0
# Not relevant: 1 a person who executes a warrant under section 21...
# 0
# Not relevant: 1 a warrant may be executed by arresting the defen...
# 0
# Not relevant: a warrant must be signed by a justice and may be d...
# 0
# Not relevant: 1 a warrant may be in form 5 and must a name or de...
# 0
# Not relevant: 1 a justice who meets the requirements under subse...
# 0
# Not relevant: in the proposed amendment are disclosed by the evi...
# 0
# Not relevant: 1 a recognizance entered into under section 105 a ...
# 0
# Not relevant: 1 if the objects of an improvement district includ...
# 0
# Not relevant: 1 if a warrant for the arrest of a defendant canno...
# 0
# Not relevant: 1 a justice may in his or her discretion ,  before...
# 0
# Not relevant: 1 a conviction or order made by the appeal court m...
# 0
# Not relevant: in relation to such applications they shall take a...
# 0
# Not relevant: in relation to a state in which two or more system...
# 0
# Not relevant: to residence or habitual residence in that state s...
# 0
# Not relevant: a contracting state with two or more territorial u...
# 0
# Not relevant: a competent authority in a territorial unit of a c...
# 0
# Not relevant: if a state has two or more territorial units in wh...
# 0
# Not relevant: federal states ,  states with more than one system...
# 0
# Not relevant: any such declaration shall be notified to the depo...
# 0
# Not relevant: if a state makes no declaration under this article...
# 0
# Not relevant: thereafter the convention shall enter into force —...
# 0
# Not relevant: a contracting state to the convention may denounce...
# 0
# Not relevant: 1 in this section ,  territorial division has the ...
# 0
# Not relevant: 1 subject to this act and the regulations made und...
# 0
# Not relevant: the lieutenant governor in council may make regula...
# 0
# Not relevant: 1 a reporting issuer must file a copy of any discl...
# 0
# Not relevant: to the provision ,  distribution ,  sale ,  purcha...
# 0
# Not relevant: in this regulation :  act means the e - health  ( ...
# 0
# Not relevant: in these rules :  accountant means a a person who ...
# 0
# Not relevant: and b a partnership and if applicable in the conte...
# 0
# Not relevant: 1 an applicant for recognition as a clearing agenc...
# 0
# Not relevant: 1 a disclosure document must include the following...
# 0
# Not relevant: person "  as defined in section 1 of the securitie...
# 1
# Relevant: scheme delivered through a provincial or territorial government of canada ,  other than the governme...
# 0
# Not relevant: of unsound mind and has been so found by a court i...
# 0
# Not relevant: ,  drying ,  freezing or any other preservation pr...
# 0
# Not relevant: by the minister on march 30 ,  2001 ,  a copy of w...
# 0
# Not relevant: the class of persons referred to in section 30  ( ...
# 0
# Not relevant: mfda named in appendix h ,  as amended from time t...
# 0
# Not relevant: investment dealer ,  mutual fund dealer or exempt ...
# 0
# Not relevant: registered dealer acting as a portfolio manager as...
# 0
# Not relevant: 1 subject to this section ,  approval is given to ...
# 0
# Not relevant: ontario ,  the government of canada or a jurisdict...
# 0
# Not relevant: any federal ,  provincial or territorial sales tax...
# 0
# Not relevant: ,  signed by the minister on january 2 ,  2018 ,  ...
# 0
# Not relevant: 1 as an exception to section 333  ( 4 )   ( a )  o...
# 0
# Not relevant: relating to bankruptcy or insolvency or was subjec...
# 0
# Not relevant: in this regulation :  act means the local governme...
# 0
# Not relevant: in the case of an offering of convertible ,  excha...
# 0
# Not relevant: payable under section 14  ( 1 )   ( b )  or 22  ( ...
# 0
# Not relevant: in this part and the regulations made under sectio...
# 1
# Relevant: sale ,  a the retail dealer who sold the fuel ,  or b a person acting on behalf of the retail dealer...
# 0
# Not relevant: describe any a penalties or sanctions imposed agai...
# 0
# Not relevant: orders act ;  notice of attachment means a notice ...
# 0
# Not relevant: 1 a maintenance order that is a made by ,  or deem...
# 0
# Not relevant: if the director is satisfied that an amount has be...
# 0
# Not relevant: 1 the minister may ,  by order ,  refer to an advi...
# 0
# Not relevant: 1 in this section ,  governing body means a body ,...
# 1
# Relevant: the minister may ,  on behalf of the government ,  enter into an agreement with one or more governme...
# 0
# Not relevant: 1 in this section ,  governing body means a body ,...
# 0
# Not relevant: 1 the minister may ,  by order ,  refer to an advi...
# 0
# Not relevant: 1 in this section ,  governing body means a body ,...
# 0
# Not relevant: 1 this section applies if ,  by the law of the cou...
# 0
# Not relevant: 1 without limiting section 335  [ interjurisdictio...
# 0
# Not relevant: 1 in this section ,  governing body means the gove...
# 0
# Not relevant: be presumed that the worker or the worker ' s depe...
# 0
# Not relevant: 1 a purchaser who purchases tangible personal prop...
# 1
# Relevant: this division does not apply in relation to the following :  a a conveyance that is subject to tax o...
# 0
# Not relevant: 1 tangible personal property is exempt from tax im...
# 0
# Not relevant: in this division :  aircraft part means a part of ...
# 0
# Not relevant: this division does not apply in relation to the fo...
# 1
# Relevant: total usage where purchase price   =   the purchase price of the taxable conveyance ;  bc usage   = ...
# 0
# Not relevant: 1 this section applies to a person who a purchases...
# 0
# Not relevant: during the year after its date of purchase ,  in b...
# 0
# Not relevant: lessee became lessee by selling the conveyance to ...
# 0
# Not relevant: lessee by selling the conveyance to the lessor und...
# 0
# Not relevant: to the government ,  in respect of the rental peri...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  this section ap...
# 1
# Relevant: stock or an interjurisdictional conveyance ,  the total distance the conveyance will travel during t...
# 0
# Not relevant: )  in relation to interjurisdictional railway roll...
# 1
# Relevant: ,  the taxable conveyance ,  and ii uses the conveyance in british columbia in the course of the per...
# 0
# Not relevant: in which the part is or is to be installed will fl...
# 1
# Relevant: :   ( a )  in relation to an interjurisdictional aircraft ,  the total number of hours the aircraft ...
# 0
# Not relevant: 1 this section applies to a person who a purchased...
# 0
# Not relevant: ,  i in the case of an aircraft ,  uses the aircra...
# 0
# Not relevant: that date ;   ( b )  in relation to an aircraft pa...
# 1
# Relevant: date the person becomes the user of the conveyance ,  in british columbia or ,  if the conveyance is...
# 0
# Not relevant: not payable under the consumption tax rebate and t...
# 0
# Not relevant: aircraft under section 49 .  3 this section does n...
# 1
# Relevant: interjurisdictional railway rolling stock or interjurisdictional conveyances ,  as those terms are d...
# 0
# Not relevant: 1 a person who is not a registrant must file a tax...
# 0
# Not relevant: act or the regulations referred to in paragraph  (...
# 0
# Not relevant: the lieutenant governor in council may make regula...
# 0
# Not relevant: a reference to a federal child support table set o...
# 0
# Not relevant: 1 the child support service must decline to recalc...
# 0
# Not relevant: order made in accordance with a section 3  ( 2 )  ...
# 0
# Not relevant: 1 the definitions set out in section 1  ( 1 )  of ...
# 0
# Not relevant: a person who a owns or operates a commercial air s...
# 0
# Not relevant: 1 in this section ,  interjurisdictional rail serv...
# 0
# Not relevant: holds a licence issued by the canadian transportat...
# 0
# Not relevant: 1 the director may issue a registered marine servi...
# 0
# Not relevant: of the interjurisdictional support orders act ,  b...
# 0
# Not relevant: ,  at least 50 %  of all the marine trips of the s...
# 0
# Not relevant: respect of fuel that is of a type or subcategory o...
# 0
# Not relevant: if the director is satisfied that a person has pai...
# 1
# Relevant: in this division :  authorized person means a the insurance corporation of british columbia ,  b a p...
# 0
# Not relevant: to have a significant impact on the child ' s rela...
# 1
# Relevant: 1 an authorized person may issue a permit under this division for a commercial vehicle registered or...
# 0
# Not relevant: mounted police as provincial police force ]  of th...
# 0
# Not relevant: a party may file ,  using form 28  [ request to fi...
# 1
# Relevant: 1 for the purposes of section 39 of the act ,  if the director is satisfied that a person has paid t...
# 0
# Not relevant: these rules do not apply to the following matters ...
# 0
# Not relevant: 1 in this rule ,  designated authority has the sam...
# 0
# Not relevant: 1 in this section ,  interjurisdictional rail serv...
# 0
# Not relevant: 1 an ifta licensee must a carry a copy of the ifta...
# 0
# Not relevant: an institute may be incorporated under this act fo...
# 0
# Not relevant: in this regulation :  act means the interjurisdict...
# 0
# Not relevant: prescribed under paragraph  ( b )  ;  d respecting...
# 0
# Not relevant: for the principal purpose of i displaying a vehicl...
# 0
# Not relevant: provisions for different commodities ,  councils ,...
# 0
# Not relevant: admission to the parks or buildings ,  or parts th...
# 0
# Not relevant: - craft ;  sale of commodities l establishing ,  m...
# 0
# Not relevant: exclusive basis ,  wholesale goods or services pri...
# 0
# Not relevant: every lease under section 5 ,  unless an exception...
# 0
# Not relevant: similar place in british columbia ,  or ii another...
# 0
# Not relevant: 1 for the purposes of this schedule and unless exc...
# 0
# Not relevant: in this instrument :  advertisement means a sales ...
# 0
# Not relevant: is provided ,  or b a purchase price is not specif...
# 0
# Not relevant: every deed under section 2 ,  unless an exception ...
# 0
# Not relevant: every mortgage under section 9 ,  unless an except...
# 0
# Not relevant: 1 a mutual fund must not do any of the following :...
# 0
# Not relevant: period ,  a discharge or remove less than 30 tonne...
# 0
# Not relevant: a person who has failed to comply with a this act ...
# 0
# Not relevant: s . b . c .  2003 ,  c .  72 ,  is confirmed and v...
# 0
# Not relevant: 1 a person must not excavate or otherwise alter la...
# 0
# Not relevant: production stops ,  vii reworking a well to alter ...
# 0
# Not relevant: 1 an order made under section 12 . 3 authorizes th...
# 0
# Not relevant: 1 a bylaw adopted by a local government under sect...
# 0
# Not relevant: a landlord must not enter a manufactured home site...
# 0
# Not relevant: the following :  a inspect anything or any activit...
# 0
# Not relevant: the minister may acknowledge the heritage value of...
# 0
# Not relevant: conditions set by the issuing authority .  5 unles...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  a person who is...
# 0
# Not relevant: 1 this section applies if a a local authority is i...
# 0
# Not relevant: 1 a person who ,  after taking an oath or making a...
# 0
# Not relevant: 1 in this section ,  light work means prescribed w...
# 0
# Not relevant: 1 in this section ,  specified action means an act...
# 0
# Not relevant: ;  f a person described in section 45  ( 1 )   ( c...
# 0
# Not relevant: 1 subject to this act ,  a recorded holder may use...
# 0
# Not relevant: in this act :  authorized person means a a certifi...
# 0
# Not relevant: 1 a permit issued under section 12 . 4  ( 1 )  may...
# 0
# Not relevant: 1 subject to subsections  ( 2 )  and  ( 3 )  and t...
# 0
# Not relevant: 1 the director of certification must suspend a let...
# 0
# Not relevant: 1 at any time between the commissioner ' s receipt...
# 0
# Not relevant: 1 the director of certification must suspend a cer...
# 0
# Not relevant: 1 in this section ,  former member means a person ...
# 0
# Not relevant: b the person whose letter of permission is suspend...
# 0
# Not relevant: if the certificate of qualification ,  independent...
# 0
# Not relevant: person ;  f a requirement for the director of cert...
# 0
# Not relevant: if a panel makes a finding under section 63  ( 1 )...
# 0
# Not relevant: if an order is made to suspend or cancel a certifi...
# 0
# Not relevant: 1 the director of certification must establish and...
# 0
# Not relevant: i prescribing a date for the purposes of section 2...
# 0
# Not relevant: 1 the minister may make regulations for the purpos...
# 0
# Not relevant: prescribing an entity for the purposes of paragrap...
# 0
# Not relevant: different letters of permissions ,  activities ,  ...
# 0
# Not relevant: a letter of permission issued under the former act...
# 0
# Not relevant: 1 if a person seizes cannabis under this act ,  th...
# 0
# Not relevant: in this act :  application for judicial review mea...
# 0
# Not relevant: 1 in this section ,  long term fees means a that p...
# 0
# Not relevant: 1 the authority may fund its operating costs and c...
# 0
# Not relevant: 2 of that act .  5 if the registrar is informed by...
# 0
# Not relevant: the minister must promptly return a bond to the bo...
# 0
# Not relevant: section 1 of the teachers act ;  certification sta...
# 0
# Not relevant: subject to section 52  ( 1 )  ,  the company may ,...
# 0
# Not relevant: 1 the minister may ,  for the purposes of subsecti...
# 0
# Not relevant: 1 in this section ,  authorized person means a a p...
# 0
# Not relevant: language instruction ,  iii solely offers a progra...
# 0
# Not relevant: a person ceases to be a member of the legislative ...
# 0
# Not relevant: 1 in this section ,  health region means a region ...
# 0
# Not relevant: 1 despite section 160 or a regulation under sectio...
# 0
# Not relevant: permitted by regulation under subsection  ( 1 )   ...
# 0
# Not relevant: 1 in this section :  applicant means a person who ...
# 0
# Not relevant: to this section ,  a director may a permit an appl...
# 0
# Not relevant: 1 the coroner may examine on oath or affirmation a...
# 0
# Not relevant: 1 if the jurors retire to consider their verdict ,...
# 0
# Not relevant: 1 the head of a public body may extend the time fo...
# 0
# Not relevant: fireworks may be sold to and discharged by a perso...
# 0
# Not relevant: 1 a financial institution must deliver written not...
# 0
# Not relevant: without the permission of the minister a person mu...
# 0
# Not relevant: 1 the authority ,  superintendent or council ,  de...
# 0
# Not relevant: 1 in this act :  appellant means a person who was ...
# 0
# Not relevant: committee and that committee must enter the reason...
# 0
# Not relevant: without limiting section 9 ,  the board may make b...
# 0
# Not relevant: 1 no approval ,  authorization ,  permit ,  certif...
# 0
# Not relevant: in this part :  certificate means a certificate of...
# 0
# Not relevant: sexual or financial abuse to vulnerable adults ;  ...
# 0
# Not relevant: 1 before a certificate or a letter of permission i...
# 0
# Not relevant: 1 a person must not carry out prescribed container...
# 0
# Not relevant: 1 subject to subsection  ( 1 . 1 )  ,  the directo...
# 0
# Not relevant: 1 with the permission of the court ,  a director o...
# 0
# Not relevant: 1 if the deputy registrar determines ,  in a crimi...
# 0
# Not relevant: the hearing ,  that person is entitled to be a par...
# 0
# Not relevant: section 1  ( 1 )   [ definitions ]  of the busines...
# 0
# Not relevant: 1 the commissioner must establish a panel ,  consi...
# 0
# Not relevant: if the registrar determines ,  in a criminal recor...
# 0
# Not relevant: subject to section 23 ,  a person must not carry o...
# 0
# Not relevant: 1 the regulator ,  on its own initiative or on app...
# 0
# Not relevant: 1 unless otherwise provided under this act ,  the ...
# 0
# Not relevant: 1 in this section :  applicable act means the fore...
# 0
# Not relevant: 1 )   ( d )  13  ( 1 )   ( c )  and  ( 3 )   ( acc...
# 0
# Not relevant: 1 a permit holder may send a notice to the regulat...
# 0
# Not relevant: conditions imposed on a permit ;  permit holder me...
# 0
# Not relevant: 1 if a permit holder begins an energy resource act...
# 0
# Not relevant: with respect to an applicant or permit holder if t...
# 0
# Not relevant: if a permit ,  a permission specified in a permit ...
# 0
# Not relevant: 1 in this section ,  former act means the pipeline...
# 0
# Not relevant: 1 in this section ,  private road means a private ...
# 0
# Not relevant: label showing the name and address of its manufact...
# 0
# Not relevant: 0 . 1 in this section ,  associate ,  in relation ...
# 0
# Not relevant: the repeal of the former act is deemed to be a per...
# 0
# Not relevant: with acceptance of same by the city ;  f purchases...
# 0
# Not relevant: the council may make by - lawsnuisances may be pro...
# 0
# Not relevant: a driver must not drive on a sidewalk ,  walkway o...
# 0
# Not relevant: 1 the council may ,  by by - law ,  identify trees...
# 0
# Not relevant: 1 an order under section 583  ( 1 )  authorizes a ...
# 0
# Not relevant: 1 the government need not obtain the permission of...
# 0
# Not relevant: 1 a person must not build a new home unless the ne...
# 0
# Not relevant: is satisfied that the person would suffer undue ha...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  an owner builde...
# 0
# Not relevant: 1 in this section ,  park ,  conservancy and recre...
# 0
# Not relevant: carrying a firearm ,  and c either i does not hold...
# 0
# Not relevant: if an angling guide does not guide or states that ...
# 0
# Not relevant: 1 on application by the holder of a guiding territ...
# 0
# Not relevant: 1 a person for whom provision is made under this d...
# 0
# Not relevant: 1 the exercise of a right held under an authorizat...
# 0
# Not relevant: 1 an order under this section may be directed to a...
# 0
# Not relevant: 1 some or all of the rights of the holder under an...
# 0
# Not relevant: the case of a use approval ,  the holder makes a m...
# 0
# Not relevant: determine whether the alleged grounds for suspensi...
# 0
# Not relevant: holders under an authorization ,  change approval ...
# 0
# Not relevant: regulations ;  k fails to comply with a term or co...
# 0
# Not relevant: 1 except as otherwise provided in this act or by r...
# 0
# Not relevant: )   ( a )  and  ( b )  and the costs determined un...
# 0
# Not relevant: the abandonment ,  suspension ,  termination or ca...
# 0
# Not relevant: 1 except with the permission and in accordance wit...
# 0
# Not relevant: 1 if the minister or an inspector ,  or a person a...
# 0
# Not relevant: 1 subject to subsections  ( 2 )  ,   ( 3 )  and  (...
# 0
# Not relevant: the person makes a report or assists in an investi...
# 0
# Not relevant: a person must not slaughter ,  destroy or dispose ...
# 0
# Not relevant: to rectify the act ,  c in the case of an employer...
# 0
# Not relevant: 1 if an application for certification is pending ,...
# 0
# Not relevant: of a fee ,  ii respecting the enforcement of a fin...
# 0
# Not relevant: 1 if a licence to do an act which without that lic...
# 0
# Not relevant: 1 the benchers may do any or all of the following ...
# 0
# Not relevant: without the permission of the person who made the ...
# 0
# Not relevant: 1 a local government may recognize the heritage va...
# 0
# Not relevant: 1 a writ of execution against an improvement distr...
# 0
# Not relevant: the order sets a time within which the constructio...
# 0
# Not relevant: ,  c the applicant has made a material misrepresen...
# 0
# Not relevant: in clause  ( a )  ,  but does not include an indiv...
# 0
# Not relevant: 1 an order under section 600  ( 1 )  authorizes a ...
# 0
# Not relevant: .  3 for the purposes of this division ,  other th...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  a board must no...
# 0
# Not relevant: when at least 3 regional trustees elected or appoi...
# 0
# Not relevant: the registrar may order a petitioner to do one or ...
# 0
# Not relevant: 1 in this section ,  authorized person means a cer...
# 0
# Not relevant: 1 the strata corporation may approve an owner ' s ...
# 0
# Not relevant: 1 subject to section 71 ,  the strata corporation ...
# 0
# Not relevant: 1 if a board receives a request from a university ...
# 0
# Not relevant: at a place that is marked ,  by use of a sign or o...
# 0
# Not relevant: 1 if one or more claims of lien under the builders...
# 0
# Not relevant: a has express permission ,  given by the owner or ...
# 0
# Not relevant: a )  or  ( b )  exceeds the amount required to cov...
# 0
# Not relevant: ;  certification mark means a stamp ,  mark ,  sea...
# 0
# Not relevant: 1 the authority may fund its operating costs and c...
# 0
# Not relevant: a provincial safety manager may exercise any or al...
# 0
# Not relevant: under section 28 ;  owner includes a lessee ;  per...
# 0
# Not relevant: person to produce for inspection any licence ,  pe...
# 0
# Not relevant: 1 a licence ,  certificate ,  permit or other perm...
# 0
# Not relevant: reasonable notice of the intention to do so ,  rem...
# 0
# Not relevant: 1 the minister or a local government that administ...
# 0
# Not relevant: 1 if required under this act ,  a person must obta...
# 0
# Not relevant: 1 a provincial safety manager may ,  in writing , ...
# 0
# Not relevant: other permission under this act to complete contin...
# 0
# Not relevant: person to whom the order is addressed ,  b specify...
# 0
# Not relevant: 1 a provincial safety manager may ,  in writing , ...
# 0
# Not relevant: 2 )  applies .  5 if satisfied that the circumstan...
# 0
# Not relevant: d . 1 be dated the day the order is made ,  e be s...
# 0
# Not relevant: a person must not do any of the following :  a ass...
# 0
# Not relevant: insurance coverage ;  e respecting the submission ...
# 0
# Not relevant: other permission ;  k respecting classes of licenc...
# 0
# Not relevant: a person commits an offence if the person sets a t...
# 0
# Not relevant: 1 in this section ,  long term fees means that por...
# 0
# Not relevant: and obligations of persons in the vicinity of regu...
# 0
# Not relevant: 1 a person who does any of the following commits a...
# 0
# Not relevant: subject only to the obtaining of permission or app...
# 0
# Not relevant: 1 if the lines or tracks of the railway of one com...
# 0
# Not relevant: the superintendent may impose conditions on any ap...
# 0
# Not relevant: 1 a director or officer of the corporation ,  a me...
# 0
# Not relevant: 1 despite sections 4 to 9  [ subdivision lots and ...
# 0
# Not relevant: a public utility that has been granted a certifica...
# 0
# Not relevant: subject to this act and the commission ' s terms o...
# 0
# Not relevant: in this division :  developer includes a former de...
# 0
# Not relevant: 1 an organization may extend the time for respondi...
# 0
# Not relevant: the commission may ,  by order ,  require every pu...
# 0
# Not relevant: 1 an attorney may make a gift or loan ,  or charit...
# 0
# Not relevant: to admit misconduct and ,  if so ,  what disciplin...
# 0
# Not relevant: 1 subject to subsection  ( 4 )  and the regulation...
# 0
# Not relevant: 1 if the discipline authority decides to accept th...
# 0
# Not relevant: file monitoring system in accordance with the mini...
# 0
# Not relevant: a person who has in any way failed to comply with ...
# 0
# Not relevant: 1 the coat of arms of british columbia is the shie...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  all records and...
# 0
# Not relevant: 1 every person carrying on business in british col...
# 0
# Not relevant: the land caused during the removal of the goods , ...
# 0
# Not relevant: the other goods caused during the removal of the a...
# 0
# Not relevant: 1 the owner of a parcel of land on which there is ...
# 0
# Not relevant: in this regulation :  act means the ticket sales a...
# 0
# Not relevant: in this regulation :  act means the teachers act ;...
# 0
# Not relevant: 1 a dealer must keep ,  at the dealer ' s principa...
# 0
# Not relevant: 1 an applicant must apply for a letter of permissi...
# 0
# Not relevant: the prescribed letter of permission fee for the pu...
# 0
# Not relevant: respect to whom the principal sent the report ;  v...
# 0
# Not relevant: respecting non - compliance with the rules .  2 th...
# 0
# Not relevant: a permission issued under the act cannot be transf...
# 0
# Not relevant: a person must not act as an escrow agent with resp...
# 0
# Not relevant: 1 a person must not cut timber that has arrived at...
# 0
# Not relevant: 1 a person ' s licence or other permissions may be...
# 0
# Not relevant: an individual must not access a hoistway or the to...
# 0
# Not relevant: unless otherwise specified by a provincial safety ...
# 0
# Not relevant: 1 a school or francophone school that registers a ...
# 0
# Not relevant: the owner of a passenger ropeway must submit to a ...
# 0
# Not relevant: 1 if a power engineer has the written permission o...
# 0
# Not relevant: 1 an individual must not perform regulated work in...
# 0
# Not relevant: despite section 76  ( 2 )  of the act ,  a right ,...
# 0
# Not relevant: 1 a person must not install a gas installation or ...
# 0
# Not relevant: 1 unless otherwise provided in the installation pe...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  an individual m...
# 0
# Not relevant: 1 subject to subsections  ( 3 )  and  ( 4 )  ,  a ...
# 0
# Not relevant: more than 14 days if the regulatory authority give...
# 0
# Not relevant: 1 if the authority or one of its subsidiaries make...
# 0
# Not relevant: 1 a person who contravenes section 5  ( 2 )  ,  7 ...
# 0
# Not relevant: 1 section 119  ( 4 )   ( a )   ( i )  and  ( ii ) ...
# 0
# Not relevant: 1 the records required to be kept under section 15...
# 0
# Not relevant: due ;  b if the letter of credit is a renewal or r...
# 0
# Not relevant: 1 section 6  ( 1 )   ( a )  and  ( b )   [ brokera...
# 0
# Not relevant: the buds of or grafting wood from a cherry tree wo...
# 0
# Not relevant: the amount covered by the letter of credit being r...
# 0
# Not relevant: 1 repealed .   [ b . c .  reg .  152 / 94 ,  s .  ...
# 0
# Not relevant: 1 for the duration of this tenancy agreement ,  th...
# 0
# Not relevant: 1 this regulation applies to all pools except the ...
# 0
# Not relevant: 1 a person may plant or grow an ornamental floweri...
# 0
# Not relevant: ,  as follows :  i the amount is paid or payable b...
# 0
# Not relevant: a person who holds or held a similar position ,  i...
# 0
# Not relevant: for the purposes of section 121  ( 2 )   ( c )  of...
# 0
# Not relevant: a landlord ,  owner or manager ,  or a person who ...
# 0
# Not relevant: in this scheme ,  unless the context otherwise req...
# 0
# Not relevant: 4 of the forest act and an approval of the chief f...
# 0
# Not relevant: to the 50th parallel of latitude ,  thence due wes...
# 0
# Not relevant: the canadian standards association ;  csa standard...
# 0
# Not relevant: not ,  but does not include muskeg ;  water produc...
# 0
# Not relevant: 1 a well permit holder must not commingle producti...
# 0
# Not relevant: 1 a well is classified as a development well if , ...
# 0
# Not relevant: to give permission to deepen a well ,  the new por...
# 0
# Not relevant: 1 of the emergency management regulation ;  facili...
# 0
# Not relevant: developed spring means a local groundwater dischar...
# 0
# Not relevant: 1 a permit holder must ensure that the duration of...
# 0
# Not relevant: all or part of a premium paid to the insurance cor...
# 0
# Not relevant: in this regulation ,  unless the context otherwise...
# 0
# Not relevant: s work experience opportunities grant program from...
# 0
# Not relevant: 12 of the environmental protection and management ...
# 0
# Not relevant: means maintain in accordance with the provisions o...
# 0
# Not relevant: is paid or payable by a person who is or was a lan...
# 0
# Not relevant: in this regulation :  act means the energy resourc...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  the operating a...
# 0
# Not relevant: relation to a dormant site ,  the person who holds...
# 0
# Not relevant: 1 a dormant site is restored for the purposes of t...
# 0
# Not relevant: )  or 3 . 02  ( 1 )   ( a )  ,  the last of the 5 ...
# 0
# Not relevant: dormant site or former site classified as a type b...
# 0
# Not relevant: in this regulation :  act means the energy resourc...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  an lng facility...
# 0
# Not relevant: 1 the requirements in this division ,  as they rel...
# 0
# Not relevant: a payday loan agreement must not contain a provisi...
# 0
# Not relevant: 1 a licensee must not carry on business in a name ...
# 0
# Not relevant: the minister must promptly return a security if a ...
# 0
# Not relevant: 1 a person who contravenes section 3 ,  4  ( 1 )  ...
# 0
# Not relevant: 1 where british columbia transit makes rules ,  or...
# 0
# Not relevant: 1 a person must not erect a structure or post a si...
# 0
# Not relevant: 1 for the purpose of section 17  ( 1 )   ( a )  of...
# 0
# Not relevant: 1 for the purpose of section 18 of the act ,  a no...
# 0
# Not relevant: 1 subject to this section and section 126 of the a...
# 0
# Not relevant: 1 a person who is required to retain records under...
# 0
# Not relevant: ensure that the amendment contains a all of the in...
# 0
# Not relevant: 1 a disclosure document must include a list of eve...
# 0
# Not relevant: 1 the term  " organic "  is adopted as a protected...
# 0
# Not relevant: if a person a does not obey a sign posted by the c...
# 0
# Not relevant: a person must not a board a ferry against the orde...
# 0
# Not relevant: for the purpose of section 20  ( c )  and  ( d )  ...
# 0
# Not relevant: 1 the treasurer or the secretary of the institute ...
# 0
# Not relevant: 1 in this rule ,  urgent application means an appl...
# 0
# Not relevant: 1 subject to subrules  ( 2 )  ,   ( 3 )  and  ( 4 ...
# 0
# Not relevant: 1 the registry that must be used for filing a form...
# 0
# Not relevant: 1 each party may have an email address for service...
# 0
# Not relevant: 1 an inmate must not a disobey a direction of a st...
# 0
# Not relevant: respondent who is not required to apply for leave ...
# 0
# Not relevant: 1 a person who contravenes section 3 ,  5 ,  6 ,  ...
# 0
# Not relevant: 1 during case management for an appeal ,  a justic...
# 0
# Not relevant: 1 subject to subrule  ( 2 )  ,  a judge or a famil...
# 0
# Not relevant: horseplay or roughhousing ,  k physically fight wi...
# 0
# Not relevant: 1 a party may ,  with permission of a judge ,  see...
# 0
# Not relevant: 1 if an applicant is required under this regulatio...
# 0
# Not relevant: with the permission of the judge or the family jus...
# 0
# Not relevant: than 30 days before the scheduled trial date ,  wi...
# 0
# Not relevant: 1 a party may discontinue all or part of an applic...
# 0
# Not relevant: 1 in this section ,  consumer means an individual ...
# 0
# Not relevant: 1 subject to subsections  ( 2 )  and  ( 3 )  ,  a ...
# 0
# Not relevant: 1 a person who is required to retain records under...
# 0
# Not relevant: 1 a person is exempted from sections 11  ( 1 )  , ...
# 0
# Not relevant: 1 if an owner or occupier of land hunts wildlife u...
# 0
# Not relevant: 1 a person is exempted from sections 11  ( 1 )  an...
# 0
# Not relevant: 1 in this section :  eligible landholder ,  in rel...
# 0
# Not relevant: 4 subject to subsection  ( 5 )  ,  a person descri...
# 0
# Not relevant: bobcat as listed in column 1 of schedule 3 . 04 , ...
# 0
# Not relevant: 1 a person must not trap on private property that ...
# 0
# Not relevant: 1 no person shall continue to hold a registered tr...
# 0
# Not relevant: 1 a person must not remove bees or beekeeping equi...
# 0
# Not relevant: a person who contravenes any of the following prov...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  the commission ...
# 0
# Not relevant: 1 a registrant may sell a drug only if a standards...
# 0
# Not relevant: in this part :  designated permit means any of the...
# 0
# Not relevant: a youth commits an infraction if the youth does an...
# 0
# Not relevant: disability ,  sex ,  sexual orientation or age ;  ...
# 0
# Not relevant: not be altered unless one of the following applies...
# 0
# Not relevant: preventive measures .  3 subsections  ( 1 )  and  ...
# 0
# Not relevant: 1 without limiting any other requirement under the...
# 0
# Not relevant: dealer act ,  d the person operates an armoured ve...
# 0
# Not relevant: a person who holds a licence or a confirmation mus...
# 0
# Not relevant: 1 a licensed game farmer must not kill ,  or permi...
# 0
# Not relevant: a special event permit must not be issued for a sp...
# 0
# Not relevant: to foreclose the borrower ' s interest in the land...
# 0
# Not relevant: 1 a permittee who holds a special event permit mus...
# 0
# Not relevant: 436  ( 1 )   ( c )  ,  in the register of members ...
# 0
# Not relevant: 1 a licensed manufacturer or licensed agent may , ...
# 0
# Not relevant: the superintendent may ,  a for the purposes of ad...
# 1
# Relevant: use in the canadian jurisdiction a particular occupational title ,  designation or abbreviated title...
# 0
# Not relevant: law similar to this act in this or another canadia...
# 0
# Not relevant: a person is qualified for the trade for which the ...
# 0
# Not relevant: in this act :  artificial means manufactured ;  ar...
# 0
# Not relevant: 1 in this section and section 33 :  apprentice mea...
# 0
# Not relevant: 1 a person must not work in a skilled trades certi...
# 1
# Relevant: in this act :  agreement means the canadian free trade agreement that entered into force on july 1 ,...
# 0
# Not relevant: satisfies the requirements in this instrument if a...
# 0
# Not relevant: the parent credit supporter is the beneficial owne...
# 0
# Not relevant: documents with a securities regulatory authority o...
# 0
# Not relevant: 1 in this section :  alternative credit support me...
# 0
# Not relevant: prospectus requirement in section 2 . 35 of nation...
# 0
# Not relevant: so long as ,  a if the insider is not the parent i...
# 0
# Not relevant: 1 in this section :  designated canadian jurisdict...
# 0
# Not relevant: ,  if the parent credit supporter is a reporting i...
# 0
# Not relevant: or iv securities issued under exemptions from the ...
# 0
# Not relevant: the parent credit supporter ;  b the credit suppor...
# 0
# Not relevant: filing by the parent credit supporter of those doc...
# 0
# Not relevant: 1 the citizens of british columbia are best served...
# 0
# Not relevant: v having a criminal record ;  vi having an educati...
# 0
# Not relevant: 1 the minister responsible may enter into a memora...
# 0
# Not relevant: 1 in addition to any other requirements set out in...
# 0
# Not relevant: does not receive ,  in the ordinary course ,  info...
# 0
# Not relevant: 1 the lieutenant governor in council may make agre...
# 1
# Relevant: refuse to issue or renew a licence under subsection  ( 1 )  if the applicant has failed to deposit a...
# 1
# Relevant: the purposes and functions of the ministry include the duty a to coordinate the activities of ,  to ...
# 0
# Not relevant: in this act :  alternative motor fuel means altern...
# 1
# Relevant: of the provincial board or a marketing board or commission may be given in any court of british colu...
# 0
# Not relevant: columbia portion of the production ,  is an indivi...
# 1
# Relevant: on the following december 31 ;  carrier means a person who owns or operates one or more motor vehicl...
# 0
# Not relevant: 1 a corporation is eligible for a basic tax credit...
# 0
# Not relevant: related to the corporation ,  and b a prescribed p...
# 0
# Not relevant: - production or a treaty co - production and for w...
# 0
# Not relevant: of the series begins before january 1 ,  2005 ,  a...
# 0
# Not relevant: 1 a corporation that has claimed or intends to cla...
# 0
# Not relevant: i )  ,  a corporation referred to in that provisio...
# 0
# Not relevant: of producing the canadian portion of the productio...
# 0
# Not relevant: following additional conditions are satisfied :  i...
# 0
# Not relevant: production ,  other than costs determined by refer...
# 1
# Relevant: 1 the director may ,  in the circumstances established by the regulations ,  a enter into an agreeme...
# 0
# Not relevant: the board shall ,  on the coming into force of thi...
# 1
# Relevant: 1 no order or regulation shall be made where the effect thereof would be to increase the aggregate o...
# 0
# Not relevant: refrigerant means a fluid that absorbs heat at a l...
# 0
# Not relevant: 1 an applicant for a recreation vehicle installati...
# 1
# Relevant: 1 in this section :  red seal credential means an interprovincial red seal credential in the trade o...
# 1
# Relevant: the board shall ,  on the coming into force of this part ,  establish by order or regulation a quota...
# 1
# Relevant: 1 no order or regulation shall be made where the effect thereof would be to increase the aggregate o...
# 0
# Not relevant: canada but outside british columbia ,  ii immediat...
# 0
# Not relevant: of subsection  ( 2 )  ,  funeral costs ,  and inte...
# 0
# Not relevant: of  " funeral costs "  ;  responsible person ,  wi...
# 1
# Relevant: ,  and g comparative transportation costs to market areas from alternative sources of production and...
# 1
# Relevant: minister ,  the lowest reasonable cost for that item or service ,  and c in respect of interprovinci...
# 0
# Not relevant: 1 in this section :  extraprovincial transportatio...
# 0
# Not relevant: nothing in section 24 exempts a person from holdin...
# 1
# Relevant: ;  iv how the services provided by ,  and the expenses of ,  the applicant will be funded ;  v the p...
# 0
# Not relevant: in this regulation ,  red seal trade means a trade...
# 1
# Relevant: gala presentation or an awards show ,  f a production that solicits funds ,  g reality television , ...
# 0
# Not relevant: the society must ,  in respect of any administrato...
# 0
# Not relevant: or an equivalent in another jurisdiction :  a doct...
# 0
# Not relevant: in part 11 of the act and this regulation :  insur...
# 1
# Relevant: category 2 alternative motor fuel or a category 3 alternative motor fuel ,  within the meaning of pa...
# 0
# Not relevant: for the purposes of the act and this regulation : ...
# 0
# Not relevant: 1 with the approval of the lieutenant governor in ...
# 0
# Not relevant: 1 a certificate ,  order ,  approval ,  rule ,  re...
# 0
# Not relevant: 1 for the purposes of this section ,  information ...
# 0
# Not relevant: is owned by the corporation ,  or b in any other c...
# 0
# Not relevant: the director in relation to processes of the indus...
# 0
# Not relevant: with the prior approval of the lieutenant governor...
# 0
# Not relevant: provincial gaming or any other business related to...
# 0
# Not relevant: an interest in the production is a tax shelter inv...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  the lottery cor...
# 0
# Not relevant: 1 the lottery corporation must not ,  under sectio...
# 1
# Relevant: 1 the lottery corporation is responsible for the conduct and management of gaming on behalf of the g...
# 0
# Not relevant: with the approval of the lieutenant governor in co...
# 0
# Not relevant: must do other things relating to gaming events tha...
# 0
# Not relevant: ancillary to the primary activity or purpose of th...
# 0
# Not relevant: )  ;  regional district means the regional distric...
# 0
# Not relevant: the community gaming grants manager ,  under the m...
# 0
# Not relevant: eligible to obtain a horse racing licence of any t...
# 0
# Not relevant: 1 in this section ,  proposed nanaimo centre bylaw...
# 0
# Not relevant: 1 in this section :  authority has the same meanin...
# 0
# Not relevant: approval or consent of the general manager or some...
# 0
# Not relevant: review the material in the context of any developm...
# 0
# Not relevant: after receiving the notice ,  must a approve the i...
# 0
# Not relevant: 1 despite the local government act but subject to ...
# 0
# Not relevant: determines how tax revenue from elk valley mines i...
# 0
# Not relevant: 1 this section applies to all current or former zo...
# 0
# Not relevant: a person ,  other than the lottery corporation ,  ...
# 0
# Not relevant: 1 in this section :  class 4 property means land ,...
# 0
# Not relevant: 1 the powers of the board shall ,  in cases specia...
# 0
# Not relevant: the board may appoint a solicitor and counsel of t...
# 0
# Not relevant: 1 the amount of money necessary to meet the requir...
# 0
# Not relevant: include a water that has a temperature less than 8...
# 0
# Not relevant: 1 for the purpose of undertakings authorized by th...
# 0
# Not relevant: it shall be lawful for any municipality within the...
# 0
# Not relevant: 1 a landlord may impose a rent increase only up to...
# 0
# Not relevant: 1 in this section ,  revenue includes interest but...
# 0
# Not relevant: 1 the board may make regulations of general applic...
# 0
# Not relevant: drilling ;  o requiring the capping or closing in ...
# 0
# Not relevant: 1 subject to section 44  [ tenant ' s compensation...
# 0
# Not relevant: must issue a mining lease for an initial term not ...
# 0
# Not relevant: 1 if a lessee complies with all prescribed require...
# 1
# Relevant: the purposes of this act whether a person meets the requirements established in the regulations for ...
# 0
# Not relevant: this act ,  sections 34  ( 3 )  and  ( 4 )  ,  48 ...
# 0
# Not relevant: 1 for the purposes of this act ,  or respecting ge...
# 0
# Not relevant: 1 on application ,  in the manner required by the ...
# 0
# Not relevant: for establishing and preserving greenbelt land ,  ...
# 0
# Not relevant: 1 a practitioner must not refer beneficiaries to a...
# 0
# Not relevant: 1 an inspector appointed under section 36  ( 2 )  ...
# 0
# Not relevant: cards or other records for the purposes of identif...
# 0
# Not relevant: section ,  the commission may ,  after giving the ...
# 0
# Not relevant: determining whether ,  in respect of the diagnosti...
# 0
# Not relevant: 1 in this section ,  conservation and heritage sit...
# 0
# Not relevant: the chief permitting officer must establish and ch...
# 0
# Not relevant: 6 if the commission takes action under subsection ...
# 0
# Not relevant: 1 the minister may ,  with the approval of the lie...
# 0
# Not relevant: renewals under this act and establishing different...
# 0
# Not relevant: daily basis for continuing contraventions or failu...
# 0
# Not relevant: 1 the minister must establish a health ,  safety a...
# 0
# Not relevant: 1 a deputy minister of the ministry ,  and other e...
# 0
# Not relevant: provide the association with the right and obligat...
# 0
# Not relevant: 1 a designated corporation and a board may be amal...
# 0
# Not relevant: approval by the labour relations board .  5 if the...
# 0
# Not relevant: 1 subject to subsection  ( 2 )  ,  the minister ma...
# 0
# Not relevant: or  ( 5 )  to the date determined by the labour re...
# 0
# Not relevant: on the actions taken by the specified municipality...
# 0
# Not relevant: subject to the approval of the lieutenant governor...
# 0
# Not relevant: the minister may a negotiate and enter into agreem...
# 0
# Not relevant: 1 the lieutenant governor in council may make regu...
# 0
# Not relevant: )  .  4 if proceedings under the expropriation act...
# 1
# Relevant: the commission to establish those terms and conditions ;  h respecting applications for approval of ...
# 0
# Not relevant: 1 in this section ,  mining exploration does not i...
# 0
# Not relevant: 1 in subsections  ( 7 )  and  ( 11 )  ,  order mea...
# 0
# Not relevant: 1 in this section ,  court means the provincial co...
# 0
# Not relevant: subsection  ( 1 )  must identify all of the follow...
# 0
# Not relevant: subsection  ( 4 )   ( a )  must identify all of th...
# 0
# Not relevant: is proposed before a proceeding for recovery of th...
# 0
# Not relevant: 1 the power to take or use land for a right of way...
# 0
# Not relevant: after a proceeding for recovery of the unliquidate...
# 0
# Not relevant: 1 the british columbia farm industry review board ...
# 0
# Not relevant: with the approval of the lieutenant governor in co...
# 0
# Not relevant: with the approval of the lieutenant governor in co...
# 0
# Not relevant: 1 in accordance with section 2 ,  the lieutenant g...
# 0
# Not relevant: 1 in accordance with section 2 ,  the lieutenant g...
# 0
# Not relevant: 1 on application by the provincial board ,  a mark...
# 0
# Not relevant: 1 the lieutenant governor in council may make regu...
# 0
# Not relevant: 1 with the approval of the lieutenant governor in ...
# 0
# Not relevant: and carrying out of schemes for the regulation of ...
# 0
# Not relevant: an approval that the lieutenant governor in counci...
# 0
# Not relevant: except with the prior approval of the supreme cour...
# 0
# Not relevant: the committee may do one or more of the following ...
# 0
# Not relevant: 1 the lieutenant governor in council may ,  on the...
# 0
# Not relevant: with the approval of the lieutenant governor in co...
# 0
# Not relevant: 1 if ,  within 2 years after filing the vesting no...
# 0
# Not relevant: approving authority modifies the expropriation und...
# 0
# Not relevant: 1 with the approval of the supreme court ,  a cura...
# 0
# Not relevant: 1 after considering the report submitted under sec...
# 0
# Not relevant: 1 the minister or ,  with the prior written approv...
# 0
# Not relevant: 1 the emergency medical assistants licensing board...
# 0
# Not relevant: c )  .  6  [ not in force .  ]  7 the licensing bo...
# 0
# Not relevant: exceed the amount available in ,  the voted approp...
# 0
# Not relevant: the commission may a employ or retain technical an...
# 0
# Not relevant: 1 subject to this section ,  a local authority may...
# 0
# Not relevant: agreement with the board of a regional district , ...
# 0
# Not relevant: 1 the government ,  in writing ,  may assign to th...
# 1
# Relevant: 1 in this section ,  information - sharing agreement includes a data - matching agreement but does n...
# 0
# Not relevant: or discretion to exempt a person or class of perso...
# 0
# Not relevant: 1 this section applies despite anything to the con...
# 0
# Not relevant: of the following provisions to continue to have ef...
# 0
# Not relevant: ,  a treaty first nation or an indigenous governin...
# 0
# Not relevant: 1 all necessary expenses required for the administ...
# 0
# Not relevant: 1 a municipality or regional district may adopt a ...
# 0
# Not relevant: 1 as a limit on the authority of a registered poli...
# 0
# Not relevant: if there is a conflict between this act or its reg...
# 0
# Not relevant: this section need not be of a capital nature ,  an...
# 0
# Not relevant: 1 in this act :  air means the atmosphere but does...
# 0
# Not relevant: 1 for the purposes of this section ,  the conduct ...
# 0
# Not relevant: 1 a person who produces or stores a hazardous wast...
# 0
# Not relevant: 1 a person who produces ,  stores ,  transports , ...
# 0
# Not relevant: a person must not discharge domestic sewage or was...
# 0
# Not relevant: or an approval includes all of the following :  a ...
# 0
# Not relevant: 1 a director may approve the introduction of waste...
# 0
# Not relevant: prohibited under section 9  [ hazardous waste stor...
# 0
# Not relevant: 1 a director may ,  subject to section 14  ( 3 )  ...
# 0
# Not relevant: discharge of the industry ,  trade ,  or business ...
# 0
# Not relevant: are required or apply in respect of the dispositio...
# 0
# Not relevant: 1 a transfer of a permit or approval is without ef...
# 0
# Not relevant: or transporting the waste ;  j changing or imposin...
# 0
# ...
# 0
# Not relevant: 1 the recorder controller and the milk pump that g...
# 0
# Not relevant: the registering party must make the appropriate en...
# 0
# Not relevant: if a claim that is not a crown charge is being reg...
# 0
# Not relevant: if a crown charge is being registered ,  the statu...
# 0
# Not relevant: 462 . 37  ( 1 )  or  ( 2 . 01 )  or 462 . 38  ( 2 ...
# 0
# Not relevant: a registration is effective until it is discharged...
# 0
# Not relevant: 1 to register a crown charge ,  the collateral mus...
# 0
# Not relevant: 1 a financing change statement must be used to reg...
# 0
# Not relevant: registering party must ,  in the appropriate space...
# 0
# Not relevant: 1 a notice of transfer in relation to a sale evide...
# 0
# Not relevant: of the motor vehicle payable only if the vehicle i...
# 0
# Not relevant: for a specified period of time .  2 an application...
# 0
# Not relevant: a motor dealer exhibiting or offering for sale a n...
# 0
# Not relevant: of all the debtor ' s interest ,  the registering ...
# 0
# Not relevant: or a certified copy of that death certificate .  4...
# 0
# Not relevant: must ,  within 7 days and on payment of copying ch...
# 0
# Not relevant: 1 if a deposit has been paid to a collector under ...
# 0
# Not relevant: 1 in this section ,  consumer has the same meaning...
# 0
# Not relevant: 1 the fees ,  charges and rents to be paid for reg...
# 0
# Not relevant: 1 the daily charge for long term care ,  treatment...
# 0
# Not relevant: for the purposes of this schedule ,  a cost statem...
# 0
# Not relevant: 5  $ 500 5 for an application to process a minor a...
# 0
# Not relevant: the queen in right of the province represented by ...
# 0
# Not relevant: inc .  records  $ 0 . 25 for each page  ( single -...
# 0
# Not relevant: all the property ,  real and personal ,  and wheth...
# 0
# Not relevant: the following conditions :  i it is a term of the ...
# 0
# Not relevant: fees may be charged under this regulation in respe...
# 0
# Not relevant: located ,  the loan or grant being made on terms a...
# 0
# Not relevant: title office as a charge against the title to the ...
# 0
# Not relevant: subject to section 6  [ when fees must not be char...
# 0
# Not relevant: 1 a provincial laboratory must not charge a fee in...
# 0
# Not relevant: of services performed or laboratory reports provid...
# 0
# Not relevant: for the performance of a service described in colu...
# 0
# Not relevant: 1 if a provincial laboratory sends ,  on its own i...
# 0
# Not relevant: for the purposes of section 18 of the act ,  a pra...
# 0
# Not relevant: the prescribed surcharge for the purposes of secti...
# 0
# Not relevant: section 21  ( 6 )  of the act ,  the amount a sell...
# 0
# Not relevant: 1 for the purposes of sampling and confirming clai...
# 0
# Not relevant: for the performance of a service described in colu...
# 0
# Not relevant: every registered mortgage broker shall a keep such...
# 0
# Not relevant: 1 for the purposes of the definition of  " specifi...
# 0
# Not relevant: the government must be determined in accordance wi...
# 0
# Not relevant: 1 in this section :  limited dealer has the meanin...
# 0
# Not relevant: for the performance of a service described in colu...
# 0
# Not relevant: 1 an inspector who acts under this regulation or s...
# 0
# Not relevant: the following fees ,  costs ,  charges and surchar...
# 0
# Not relevant: under 19 years of age ,  apply in person for the c...
# 0
# Not relevant: in this regulation :  act means the motor vehicle ...
# 0
# Not relevant: 1 for the purposes of section 3  ( b )  ,  the tra...
# 0
# Not relevant: 1 the fees under division 7  [ registration of not...
# 0
# Not relevant: for the purposes of section 214 . 5  ( a )  of the...
# 0
# Not relevant: in this instrument ,  affiliated entity has the me...
# 0
# Not relevant: in this division ,  conviction includes the granti...
# 0
# Not relevant: employees of the government of british columbia in...
# 0
# Not relevant: gaining access to water from the stream ,  ii any ...
# 0
# Not relevant: such an order ;  f a stream or aquifer to which an...
# 0
# Not relevant: 1 the surcharge payable for a guide outfitter lice...
# 0
# Not relevant: employee of the owner or occupier who discharges a...
# 0
# Not relevant: a person is exempt from section 32 of the wildlife...
# 0
# Not relevant: 1 for the purposes of this regulation ,  each of t...
# 0
# Not relevant: an applicant for a guide outfitter licence commits...
# 0
# Not relevant: 1 an authorized person must not ,  under this part...
# 0
# Not relevant: or part of a classified water that is an item in c...
# 0
# Not relevant: pitless adapter means a mechanical device attached...
# 0
# Not relevant: for the purposes of section 14 of the act ,  the n...
# 0
# Not relevant: 1 the fee and surcharge payable for a transporter ...
# 0
# Not relevant: 1 an individual who is ordinarily resident in cana...
# 0
# Not relevant: 1 a person who holds angler day quota must pay ann...
# 0
# Not relevant: 1 a well identification plate required under this ...
# 0
# Not relevant: 1 the person responsible for deactivating a water ...
# 0
# Not relevant: the owner of a recharge well or injection well con...
# 0
# Not relevant: 1 the successful applicant for a licence to guide ...
# 0
# Not relevant: 1 for the purposes of section 116  ( 1 )   [ recor...
# 0
# Not relevant: including business name ,  if any ,  address ,  te...
# 0
# Not relevant: for the purposes of section 278  ( 7 )   [ appeal ...
# 0
# Not relevant: 1 if a licensee in respect of a power development ...
# 0
# Not relevant: a licensee is not required to pay annual rentals i...
# 0
# Not relevant: the minister may not charge to a health profession...
# 0
# Not relevant: kilowatts ;  efficiency factor means a factor appl...
# 0
# Not relevant: 1 a registrant may prescribe ,  dispense or admini...
# 0
# Not relevant: 1 in this regulation :  act means the water sustai...
# 0
# Not relevant: the registrant has successfully completed a certif...
# 0
# Not relevant: securityholders under u . s .  federal securities ...
# 0
# Not relevant: is set out in the prescription ,  inform the named...
# 0
# Not relevant: ,  free of charge ,  a legible written or electron...
# 0
# Not relevant: 1 an individual applicant for a licence must provi...
# 0
# Not relevant: 1 a complete set of accounting records must be mai...
# 0
# Not relevant: documents incorporated by reference or deemed to b...
# 0
# Not relevant: a sheriff ,  bailiff or other person who enforces ...
# 0
# Not relevant: for the purpose of discharging a patient from a ho...
# 0
# Not relevant: 1 the use of agricultural land for conducting an a...
# 0
# Not relevant: 1 a document regarding a patient who ,  as an in -...
# 0
# Not relevant: 1 the person in charge of a youth custody centre i...
# 0
# Not relevant: from a farm use but does not include water ;  gath...
# 0
# Not relevant: record of the patient do not show that it is neces...
# 0
# Not relevant: 1 the person in charge of a youth custody centre m...
# 0
# Not relevant: of subsection  ( 3 )   ( a )  and  ( b )  ,  the p...
# 0
# Not relevant: 1 repealed .   [ b . c .  reg .  220 / 2009 ,  s ....
# 0
# Not relevant: 35  ( 2 )   [ reintegration leave and day absences...
# 0
# Not relevant: 1 a decision to order a consequence under section ...
# 0
# Not relevant: as soon as practicable ,  to the person in charge ...
# 0
# Not relevant: 1 if a staff member believes on reasonable grounds...
# 0
# Not relevant: 1 in this section ,  section 18 and the act ,  str...
# 0
# Not relevant: .  4 the authorized person referred to in subsecti...
# 0
# Not relevant: the assessment for the property to determine wheth...
# 0
# Not relevant: an authorized person conducting a strip search und...
# 0
# Not relevant: relationship .  2 a person is not eligible for a p...
# 0
# Not relevant: 1 in this section :  frisk search means a hand sea...
# 0
# Not relevant: g652 1 . 00 g653 1 . 45 g655 1 . 95 table 3 — base...
# 0
# Not relevant: 1 for the purposes of section 132  ( 2 )   ( f )  ...
# 0
# Not relevant: a municipality that comprises part of the capital ...
# 0
# Not relevant: any sex or gender ,  together with the facilities ...
# 0
# Not relevant: for the purposes of section 82  ( 6 )  of the act ...
# 0
# Not relevant: 1 an independent school that registers a child und...
# 0
# Not relevant: 1 an adoption agency must not charge pre - adoptio...
# 0
# Not relevant: of the class ,  or iii if ,  in the opinion of the...
# 0
# Not relevant: for the purposes of section 7  ( 6 )   ( c )   ( i...
# 0
# Not relevant: d the date and time the variation ,  correction or...
# 0
# Not relevant: 1 a person who stores a pesticide must store it in...
# 0
# Not relevant: that is a benefit under plan s for the purpose of ...
# 0
# Not relevant: in this division :  clinical need means any of the...
# 0
# Not relevant: 1 the premium for each crop year must be determine...
# 0
# Not relevant: is living accommodation that will be provided i on...
# 0
# Not relevant: 1 on receipt of an inquiry from an owner of a new ...
# 0
# Not relevant: affiliated with another person who engages in the ...
# 0
# Not relevant: section 397  [ imposition of fees and charges ]  o...
# 0
# Not relevant: 1 the following categories of eligible development...
# 0
# Not relevant: 1 a local government may retain from money collect...
# 0
# Not relevant: for each category listed in column 1 in the follow...
# 0
# Not relevant: no interest is payable on the unpaid balance of a ...
# 0
# Not relevant: a developer liable to pay a charge may elect to pa...
# 0
# Not relevant: where a developer elects to pay the charge by inst...
# 0
# Not relevant: of a neutral if the court is satisfied that the ne...
# 0
# Not relevant: 1 subject to this section ,  the greater vancouver...
# 0
# Not relevant: 1 no later than 28 days after the settlement proce...
# 0
# Not relevant: of a neutral if the court is satisfied that the ne...
# 0
# Not relevant: 1 for the purposes of section 121  ( 1 )   ( f )  ...
# 0
# Not relevant: except where a contrary intention appears ,  a ref...
# 0
# Not relevant: subject to section 3 ,  the registration requireme...
# 0
# Not relevant: interest charged under section 26  ( 1 )  ,   ( 2 ...
# 0
# Not relevant: 1 no later than 28 days after the settlement proce...
# 0
# Not relevant: the charges ,  the corporation must pay to the ins...
# 0
# Not relevant: 1 for the purposes of section 121  ( 1 )   ( f )  ...
# 0
# Not relevant: part 10 of the act to or on behalf of the insured ...
# 0
# Not relevant: 1 a participating dealer or representative of a pa...
# 0
# Not relevant: .  3 if ,  after all rights of appeal are exhauste...
# 0
# Not relevant: 1 for the purposes of section 127 of the act ,  ex...
# 0
# Not relevant: a marketplace must publicly disclose ,  on its web...
# 0
# Not relevant: )  or  ( b )  even if they exceed expenses that wo...
# 0
# Not relevant: the fund ,  that has a significant interest in the...
# 0
# Not relevant: 1 if a portfolio adviser of an investment fund rec...
# 0
# Not relevant: and k investors are informed annually of their rig...
# 0
# Not relevant: 1 an agreement or declaration of trust by which a ...
# 0
# Not relevant: sub - adviser a to exercise the powers and dischar...
# 0
# Not relevant: in subsection  ( 1 )  to finance its own or any ot...
# 0
# Not relevant: the following are exempt from section 6 of the act...
# 0
# Not relevant: the purpose of a remitting to the mutual fund or t...
# 0
# Not relevant: or participating dealer ,  or of a person or compa...
# 0
# Not relevant: a sales communication for an asset allocation serv...
# 0
# Not relevant: a principal distributor or participating dealer , ...
# 0
# Not relevant: and does  [ do ]  not take into account sales ,  r...
# 0
# Not relevant: contains performance data must contain a a warning...
# 0
# Not relevant: ]  of the investment fund and may receive less tha...
# 0
# Not relevant: 1 an investment fund that is not a corporation mus...
# 0
# Not relevant: ]  and does not represent an actual one year retur...
# 0
# Not relevant: 1 a person or company must not describe a mutual f...
# 0
# Not relevant: prospectus of the mutual fund .  2 if a sales comm...
# 0
# Not relevant: 1 the standard performance data of an investment f...
# 0
# Not relevant: the performance measurement period .  5 .  there a...
# 0
# Not relevant: an investment fund ,  the redeemable value and ini...
# 0
# Not relevant: measurement period ;   ( b )  if structured in a m...
# 0
# Not relevant: ;  standard performance data means ,  as calculate...
# 0
# Not relevant: 1 if ,  during or after a performance measurement ...
# 0
# Not relevant: 1 a u - brew and u - vin licence authorizes a a li...
# 0
# Not relevant: 1 the following assumptions must be made in the ca...
# 0
# Not relevant: 1 a licensee must ensure that a customer is not al...
# 0
# Not relevant: 1 where a subdivision plan tendered under section ...
# 0
# Not relevant: fees paid by an account of the size referred to in...
# 0
# Not relevant: 1 where an indefeasible title has been registered ...
# 0
# Not relevant: where a transmission occurs as a result of a death...
# 0
# Not relevant: or agreement to renew a lease ,  g an option to pu...
# 0
# Not relevant: 1 in return for the lender agreeing to lend the pr...
# 0
# Not relevant: and agreements .  5 when the borrower has paid the...
# 0
# Not relevant: are registered in the land title office at the tim...
# 0
# Not relevant: 1 interest is chargeable on the mortgage money and...
# 0
# Not relevant: the land title office against the land within 30 d...
# 0
# Not relevant: 1 a default occurs under this mortgage if a the bo...
# 0
# Not relevant: s intention to terminate the lease before the term...
# 0
# Not relevant: 1 division 6 of part 14 of the act does not apply ...
# 0
# Not relevant: the lender asks the borrower to insure against ,  ...
# 0
# Not relevant: 1 this section applies if the interest mortgaged s...
# 0
# Not relevant: other cause ;  d pay any money that might ,  if no...
# 0
# Not relevant: 1 this section applies if the land described in th...
# 0
# Not relevant: all or part of the land ,  h may manage the land a...
# 0
# Not relevant: 1 a licensee must not a provide unlimited or unspe...
# 0
# Not relevant: if the mortgage form states that this mortgage sec...
# 0
# Not relevant: borrower is entitled to inspect or obtain .  6 if ...
# 0
# Not relevant: 1 in addition to the information required under se...
# 0
# Not relevant: 1 in this section :  owner means an owner of eligi...
# 0
# Not relevant: 1 if the land is subdivided a this mortgage will c...
# 0
# Not relevant: 1 in this section ,   " delivery service "  means ...
# 0
# Not relevant: delivery service charge ;  e the owner keeps a cop...
# 0
# Not relevant: an agreement to mediate referred to in section 13 ...
# 0
# Not relevant: 1 in this section :  amending agreement has the sa...
# 0
# Not relevant: 1 as the lender would not have agreed to lend the ...
# 0
# Not relevant: as a term of that agreement :  i a holder of a reg...
# 0
# Not relevant: for the purposes of section 46  ( 2 )   ( a )  of ...
# 0
# Not relevant: 1 an inspector may cause any livestock to be detai...
# 0
# Not relevant: in the act and this regulation :  beer means beer ...
# 0
# Not relevant: the following rules and requirements apply to a ca...
# 0
# Not relevant: 1 the following rules and requirements apply to a ...
# 0
# Not relevant: for the purposes of section 20  ( 6 )   ( b )   [ ...
# 1
# Relevant: a licensed manufacturer must keep in a manner satisfactory to the general manager the following reco...
# 0
# Not relevant: an elector organization disclosure statement must ...
# 0
# Not relevant: a candidate disclosure statement must include the ...
# 0
# Not relevant: of obtaining funds for campaign use ,  and ii the ...
# 0
# Not relevant: those services for the purpose of obtaining funds ...
# 0
# Not relevant: an elector organization disclosure statement must ...
# 0
# Not relevant: a candidate disclosure statement must include the ...
# 0
# Not relevant: 1 this section does not apply in british columbia ...
# 0
# Not relevant: ]  by providing the contact with an email address ...
# 0
# Not relevant: 1 in british columbia ,  québec and new brunswick ...
# 0
# Not relevant: property or services for the purpose of obtaining ...
# 0
# Not relevant: address or address ,  as applicable .  "  2 in bri...
# 0
# Not relevant: 1 on request by a person or company ,  a scholarsh...
# 0
# Not relevant: 1 in this section ,  no - trailing - commission et...
# 0
# Not relevant: 1 an etf must deliver or send to any person or com...
# 238 relevant nodes found

# %% [markdown]
# #### 7. Convert to CSV

# %%
import json
import pandas as pd


def jsonl_to_csv(jsonl_file, csv_file):
    """
    Convert a JSONL file to CSV format

    Args:
      jsonl_file (str): Path to the input JSONL file
      csv_file (str): Path to the output CSV file
    """
    # Read JSONL file
    with open(jsonl_file, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f]

    # Convert to DataFrame for easier handling
    df = pd.DataFrame(data)

    # Write to CSV
    df.to_csv(csv_file, index=False)
    print(f"Converted {jsonl_file} to {csv_file}")

input_file = "related_nodes_V4.jsonl"
output_file = "related_nodes_V4.csv"
jsonl_to_csv(input_file, output_file)
# Out:
# Converted related_nodes.jsonl to related_nodes_V4.csv
